# %%
# 클럽 리스트 확인

import pandas as pd
import numpy as np

c_df = pd.read_csv('./club_list_2.csv')
c_df
# Out:
#         id    club_name                                  club_info  \
# 0       21       뜨개질 모임                                        NaN
# 1       22       나가노 마켓                                      수정완료?
# 2       26       틴틴팅클링링                                        NaN
# 3       48  미니어쳐 공예 클래스  취미 관련 정보를 교환하고 함께 성장하는 미니어쳐 공예 클래스 모임입니다.
# 4       52           순간        순간 모임은 취미에 대한 열정을 가진 사람들이 모이는 곳입니다.
# ...    ...          ...                                        ...
# 1024  1007         작가학교        작가학교 모임에서는 스터디에 관한 다양한 주제로 활동을 합니다.
# 1025  1008         베누스토        베누스토 모임에서는 스터디에 관한 다양한 주제로 활동을 합니다.
# 1026  1009    꼼지락 생각 모임   꼼지락 생각 모임 모임에서는 스터디에 관한 다양한 주제로 활동을 합니다.
# 1027    14          야시장                                      ㅈㄷㄱ쇼ㅕ
# 1028    35          꼬꼬봉          기타 관련 정보를 교환하고 함께 성장하는 꼬꼬봉 모임입니다.
#
#       club_main_category_id category_name
# 0                         1            취미
# 1                         1            취미
# 2                         1            취미
# 3                         1            취미
# 4                         1            취미
# ...                     ...           ...
# 1024                     11           스터디
# 1025                     11           스터디
# 1026                     11           스터디
# 1027                     12          지역축제
# 1028                     13            기타
#
# [1029 rows x 5 columns]

# %% [markdown]
# ### 아래 이미지 추가

# %%
# value_counts 결과를 DataFrame으로 변환
counts = c_df[['club_main_category_id', 'category_name']].value_counts().reset_index(name='counts')

# club_main_category_id를 기준으로 정렬
sorted_counts = counts.sort_values(by='club_main_category_id')

# 결과 출력
sorted_counts
# Out:
#     club_main_category_id category_name  counts
# 1                       1            취미     166
# 3                       2         문화·예술     140
# 0                       3       운동·액티비티     206
# 6                       4        푸드·드링크      46
# 4                       5         여행·동행     110
# 2                       6       성장·자기개발     152
# 9                       7         동네·또래      37
# 8                       8        연애·소개팅      38
# 10                      9           재테크      16
# 7                      10           외국어      46
# 5                      11           스터디      70
# 11                     12          지역축제       1
# 12                     13            기타       1

# %% [markdown]
# ### 아래 이미지 추가

# %%
# 랜덤 titile 확인

import pandas as pd
import numpy as np

# CSV 파일 목록
file_list = ['./youtube_another.csv', './youtube_culture.csv', './youtube_festival.csv', 
             './youtube_food.csv', './youtube_hobby.csv', './youtube_love.csv',
             './youtube_sport.csv', './youtube_stock.csv', './youtube_travel.csv']

# 각 CSV 파일을 읽어서 데이터프레임 리스트로 저장
df_list = [pd.read_csv(file) for file in file_list]

# 모든 데이터프레임을 세로로 결합
all_df = pd.concat(df_list, axis=0, ignore_index=True)

# 결과 출력
all_df
# Out:
#              created_date         updated_date  \
# 0     2024-04-24 12:29:30  2024-05-19 22:28:02
# 1     2024-02-06 15:32:27  2024-05-19 22:28:02
# 2     2024-02-19 14:04:46  2024-05-19 22:28:02
# 3     2024-02-09 21:23:57  2024-05-19 22:28:02
# 4      2024-03-23 8:07:11  2024-05-19 22:28:02
# ...                   ...                  ...
# 4113  2024-02-12 21:30:49  2024-05-19 22:49:17
# 4114  2024-02-26 17:43:57  2024-05-19 22:49:17
# 4115   2024-05-18 9:08:10  2024-05-19 22:49:17
# 4116   2024-05-02 0:22:33  2024-05-19 22:49:17
# 4117   2024-03-09 7:42:33  2024-05-19 22:49:17
#
#                                          teenplay_title  \
# 0     걸그룹 ♬♡ 최신 노래 시원하게 말아줄게 ♬ M/V 4K 뮤비 노래 모음 플리 30...
# 1      걸그룹 ♬♡ 트리플에스 (tripleS) M/V 4K 뮤비 노래 모음 플리 10곡 ♬♡
# 2           추억이 된 걸그룹 ♬♡ 여자친구 뮤비 노래 모음 플리 14곡 ♬♡ (재업로드)
# 3     미친 연습량 걸그룹 ♬♡ 퍼포먼스 비디오 노동요 ♬ M/V 4K 뮤비 노래 모음 플...
# 4          걸그룹 트와이스 ♬♡ 솔로곡 포함 M/V 4K 뮤비 노래 모음 플리 26곡 ♬♡
# ...                                                 ...
# 4113  아제르바이잔 진흙 화산에서 머드목욕을 하고 왔습니다. 머드 볼케이노 머드팩 체험여행...
# 4114  아제르바이잔 3,000원 점심식사 든든하게 해결하고 왔습니다. 3000원 아제르 가...
# 4115    아제르바이잔의 아파트는 어떻게 생겼을까? 해외 아파트 월세는 얼마일까? 사는집 공개!
# 4116                         아제르바이잔 밤길은 과연 안전할까? 치안테스트!
# 4117  아제르바이잔 현지 시장에서 돼지고기 사서 보쌈해먹기 요리&먹방 Pork mukban...
#
#                                        video_path  \
# 0     teenplay_video/2024/03/25/another_video.MOV
# 1     teenplay_video/2024/04/07/another_video.MOV
# 2     teenplay_video/2024/05/08/another_video.MOV
# 3     teenplay_video/2024/03/26/another_video.MOV
# 4     teenplay_video/2024/04/06/another_video.MOV
# ...                                           ...
# 4113   teenplay_video/2024/01/07/travel_video.MOV
# 4114   teenplay_video/2024/01/28/travel_video.MOV
# 4115   teenplay_video/2024/02/21/travel_video.MOV
# 4116   teenplay_video/2024/01/11/travel_video.MOV
# 4117   teenplay_video/2024/01/12/travel_video.MOV
#
#                                           thumnail_path  status  \
# 0     teenplay_thumbnail/2024/02/09/another_thumnail...     1.0
# 1     teenplay_thumbnail/2024/02/11/another_thumnail...     1.0
# 2     teenplay_thumbnail/2024/03/09/another_thumnail...     1.0
# 3     teenplay_thumbnail/2024/02/23/another_thumnail...     1.0
# 4     teenplay_thumbnail/2024/05/08/another_thumnail...     1.0
# ...                                                 ...     ...
# 4113  teenplay_thumbnail/2024/03/05/travel_thumnail.png     1.0
# 4114  teenplay_thumbnail/2024/02/09/travel_thumnail.png     1.0
# 4115  teenplay_thumbnail/2024/04/14/travel_thumnail.png     1.0
# 4116  teenplay_thumbnail/2024/05/12/travel_thumnail.png     1.0
# 4117  teenplay_thumbnail/2024/05/09/travel_thumnail.png     1.0
#
#      club_main_category_id  club_id
# 0                       기타      NaN
# 1                       기타      NaN
# 2                       기타      NaN
# 3                       기타      NaN
# 4                       기타      NaN
# ...                    ...      ...
# 4113                 여행·동행      NaN
# 4114                 여행·동행      NaN
# 4115                 여행·동행      NaN
# 4116                 여행·동행      NaN
# 4117                 여행·동행      NaN
#
# [4118 rows x 8 columns]

# %%
all_df['club_main_category_id'].unique()
# Out:
# array(['기타', '문화·예술', nan, '동네·또래', '푸드·드링크', '취미', '연애·소개팅', '운동·액티비티',
#        '성장·자기개발', '여행·동행'], dtype=object)

# %%
import pandas as pd
import numpy as np


# 각 카테고리에 해당하는 id 값 리스트 생성
id_lists = {
    '취미': c_df[c_df['category_name'] == '취미']['id'].tolist(),
    '문화·예술': c_df[c_df['category_name'] == '문화·예술']['id'].tolist(),
    '운동·액티비티': c_df[c_df['category_name'] == '운동·액티비티']['id'].tolist(),
    '푸드·드링크': c_df[c_df['category_name'] == '푸드·드링크']['id'].tolist(),
    '여행·동행': c_df[c_df['category_name'] == '여행·동행']['id'].tolist(),
    '성장·자기개발': c_df[c_df['category_name'] == '성장·자기개발']['id'].tolist(),
    '연애·소개팅': c_df[c_df['category_name'] == '연애·소개팅']['id'].tolist(),
    '재테크': c_df[c_df['category_name'] == '재테크']['id'].tolist(),
    '외국어': c_df[c_df['category_name'] == '외국어']['id'].tolist(),
    '스터디': c_df[c_df['category_name'] == '스터디']['id'].tolist(),
    '지역축제': c_df[c_df['category_name'] == '지역축제']['id'].tolist(),
    '기타': c_df[c_df['category_name'] == '기타']['id'].tolist()
}

# club_id 열 추가하고 조건에 맞는 경우 랜덤 값 할당, 그렇지 않은 경우 NaN 할당
all_df['club_id'] = np.nan  # 초기값은 NaN으로 설정

for category, id_list in id_lists.items():
    all_df.loc[all_df['club_main_category_id'] == category, 'club_id'] = np.random.choice(id_list, size=(all_df['club_main_category_id'] == category).sum(), replace=True)

# 결측치에 대해 '문화·예술' 리스트에서 랜덤 값 할당
all_df['club_id'] = all_df['club_id'].apply(lambda x: np.random.choice(id_lists['문화·예술']) if pd.isna(x) else x)

# 결과 출력
all_df
# Out:
#              created_date         updated_date  \
# 0     2024-04-24 12:29:30  2024-05-19 22:28:02
# 1     2024-02-06 15:32:27  2024-05-19 22:28:02
# 2     2024-02-19 14:04:46  2024-05-19 22:28:02
# 3     2024-02-09 21:23:57  2024-05-19 22:28:02
# 4      2024-03-23 8:07:11  2024-05-19 22:28:02
# ...                   ...                  ...
# 4113  2024-02-12 21:30:49  2024-05-19 22:49:17
# 4114  2024-02-26 17:43:57  2024-05-19 22:49:17
# 4115   2024-05-18 9:08:10  2024-05-19 22:49:17
# 4116   2024-05-02 0:22:33  2024-05-19 22:49:17
# 4117   2024-03-09 7:42:33  2024-05-19 22:49:17
#
#                                          teenplay_title  \
# 0     걸그룹 ♬♡ 최신 노래 시원하게 말아줄게 ♬ M/V 4K 뮤비 노래 모음 플리 30...
# 1      걸그룹 ♬♡ 트리플에스 (tripleS) M/V 4K 뮤비 노래 모음 플리 10곡 ♬♡
# 2           추억이 된 걸그룹 ♬♡ 여자친구 뮤비 노래 모음 플리 14곡 ♬♡ (재업로드)
# 3     미친 연습량 걸그룹 ♬♡ 퍼포먼스 비디오 노동요 ♬ M/V 4K 뮤비 노래 모음 플...
# 4          걸그룹 트와이스 ♬♡ 솔로곡 포함 M/V 4K 뮤비 노래 모음 플리 26곡 ♬♡
# ...                                                 ...
# 4113  아제르바이잔 진흙 화산에서 머드목욕을 하고 왔습니다. 머드 볼케이노 머드팩 체험여행...
# 4114  아제르바이잔 3,000원 점심식사 든든하게 해결하고 왔습니다. 3000원 아제르 가...
# 4115    아제르바이잔의 아파트는 어떻게 생겼을까? 해외 아파트 월세는 얼마일까? 사는집 공개!
# 4116                         아제르바이잔 밤길은 과연 안전할까? 치안테스트!
# 4117  아제르바이잔 현지 시장에서 돼지고기 사서 보쌈해먹기 요리&먹방 Pork mukban...
#
#                                        video_path  \
# 0     teenplay_video/2024/03/25/another_video.MOV
# 1     teenplay_video/2024/04/07/another_video.MOV
# 2     teenplay_video/2024/05/08/another_video.MOV
# 3     teenplay_video/2024/03/26/another_video.MOV
# 4     teenplay_video/2024/04/06/another_video.MOV
# ...                                           ...
# 4113   teenplay_video/2024/01/07/travel_video.MOV
# 4114   teenplay_video/2024/01/28/travel_video.MOV
# 4115   teenplay_video/2024/02/21/travel_video.MOV
# 4116   teenplay_video/2024/01/11/travel_video.MOV
# 4117   teenplay_video/2024/01/12/travel_video.MOV
#
#                                           thumnail_path  status  \
# 0     teenplay_thumbnail/2024/02/09/another_thumnail...     1.0
# 1     teenplay_thumbnail/2024/02/11/another_thumnail...     1.0
# 2     teenplay_thumbnail/2024/03/09/another_thumnail...     1.0
# 3     teenplay_thumbnail/2024/02/23/another_thumnail...     1.0
# 4     teenplay_thumbnail/2024/05/08/another_thumnail...     1.0
# ...                                                 ...     ...
# 4113  teenplay_thumbnail/2024/03/05/travel_thumnail.png     1.0
# 4114  teenplay_thumbnail/2024/02/09/travel_thumnail.png     1.0
# 4115  teenplay_thumbnail/2024/04/14/travel_thumnail.png     1.0
# 4116  teenplay_thumbnail/2024/05/12/travel_thumnail.png     1.0
# 4117  teenplay_thumbnail/2024/05/09/travel_thumnail.png     1.0
#
#      club_main_category_id  club_id
# 0                       기타     35.0
# 1                       기타     35.0
# 2                       기타     35.0
# 3                       기타     35.0
# 4                       기타     35.0
# ...                    ...      ...
# 4113                 여행·동행    898.0
# 4114                 여행·동행    694.0
# 4115                 여행·동행    728.0
# 4116                 여행·동행    595.0
# 4117                 여행·동행    728.0
#
# [4118 rows x 8 columns]

# %%
result_df = all_df.drop(labels = ['club_main_category_id'], axis =1)
result_df
result_df.to_csv('result.csv', index=False, encoding='utf-8-sig')

# %%
pre_t_df = all_df.drop(labels = ['teenplay_title', 'club_id', 'created_date', 'updated_date', 'video_path', 'thumnail_path', 'status'], axis =1)
pre_t_df
# Out:
#      club_main_category_id
# 0                       기타
# 1                       기타
# 2                       기타
# 3                       기타
# 4                       기타
# ...                    ...
# 4113                 여행·동행
# 4114                 여행·동행
# 4115                 여행·동행
# 4116                 여행·동행
# 4117                 여행·동행
#
# [4118 rows x 1 columns]

# %%
def assign_value_based_on_column(value):
    if value =='취미':
        return 1
    elif value == "문화·예술":
        return 2
    elif value == "운동·액티비티":
        return 3
    elif value == "푸드·드링크":
        return 4
    elif value == "여행·동행":
        return 5
    elif value == "성장·자기개발":
        return 6
    elif value == "동네·또래":
        return 7
    elif value == "연애·소개팅":
        return 8
    elif value == "재테크":
        return 9
    elif value == "외국어":
        return 10
    elif value == "스터디":
        return 11
    elif value == "지역축제":
        return 12
    else:
        return 13

# %% [markdown]
# ### 아래 데이터 프레임 이미지 복사

# %%
pre_t_df['club_main_category_id'] = pre_t_df['club_main_category_id'].apply(assign_value_based_on_column)
pre_t_df
# Out:
#       club_main_category_id
# 0                        13
# 1                        13
# 2                        13
# 3                        13
# 4                        13
# ...                     ...
# 4113                      5
# 4114                      5
# 4115                      5
# 4116                      5
# 4117                      5
#
# [4118 rows x 1 columns]

# %%
import numpy as np
# 1부터 13까지의 숫자 중 12를 제외한 리스트
choices = list(range(1, 12)) + [13]
choices_2 = list(range(1, 14))

# 예제 데이터프레임이므로 user_like_category와 user_category(target) 열을 임의로 생성
pre_t_df['user_like_category'] = np.random.choice(choices, size=len(all_df))
pre_t_df['wish_list_category'] = np.random.choice(choices, size=len(all_df))
# pre_t_df['user_category(target)'] = np.random.choice(choices, size=len(all_df))
pre_t_df


# # # club_id 열을 조건부 할당하여 추가
# all_df['club_category'] = all_df['club_main_category_id'].apply(assign_value_based_on_column)

# # # 결과 출력
display(pre_t_df)
# Out:
#       club_main_category_id  user_like_category  wish_list_category
# 0                        13                   9                   9
# 1                        13                   4                   8
# 2                        13                   7                   9
# 3                        13                   8                   3
# 4                        13                  11                   9
# ...                     ...                 ...                 ...
# 4113                      5                   2                   3
# 4114                      5                  10                   5
# 4115                      5                   6                   1
# 4116                      5                   9                   9
# 4117                      5                  10                   5
#
# [4118 rows x 3 columns]

# %%
def match_categories(df, like_col, target_col, ratio=(3, 7)):
    like_values = df[like_col].value_counts().index
    for value in like_values:
        like_indices = df[df[like_col] == value].index
        num_target = int(len(like_indices) * ratio[1] / sum(ratio))
        target_indices = np.random.choice(like_indices, size=num_target, replace=False)
        df.loc[target_indices, target_col] = value
    return df

# %%
# # club_category(target) 열 생성
pre_t_df['user_category'] = np.nan

# user_like_category와 club_category(target) 값을 3:7 비율로 맞춤
pre_t_df = match_categories(pre_t_df, 'club_main_category_id', 'user_category')

# 결측치 채우기: 남아 있는 결측치에 대해 임의의 값으로 채움 (여기서는 같은 비율로 채우기)
remaining_indices = pre_t_df['user_category'].isna()
num_remaining = remaining_indices.sum()
if num_remaining > 0:
    remaining_values = np.random.choice(pre_t_df['club_main_category_id'].unique(), size=num_remaining, replace=True)
    pre_t_df.loc[remaining_indices, 'user_category'] = remaining_values


# 결과 출력
pre_t_df['user_category'] = pre_t_df['user_category'].astype(np.int64)
pre_t_df
# Out:
#       club_main_category_id  user_like_category  wish_list_category  \
# 0                        13                   9                   9
# 1                        13                   4                   8
# 2                        13                   7                   9
# 3                        13                   8                   3
# 4                        13                  11                   9
# ...                     ...                 ...                 ...
# 4113                      5                   2                   3
# 4114                      5                  10                   5
# 4115                      5                   6                   1
# 4116                      5                   9                   9
# 4117                      5                  10                   5
#
#       user_category
# 0                13
# 1                13
# 2                13
# 3                13
# 4                13
# ...             ...
# 4113              5
# 4114              5
# 4115             13
# 4116              7
# 4117              5
#
# [4118 rows x 4 columns]

# %% [markdown]
# ### 이미지 복사

# %%
target_column = pre_t_df.pop('club_main_category_id')
pre_t_df['club_main_category_id(target)'] = target_column
pre_t_df
# Out:
#       user_like_category  wish_list_category  user_category  \
# 0                      9                   9             13
# 1                      4                   8             13
# 2                      7                   9             13
# 3                      8                   3             13
# 4                     11                   9             13
# ...                  ...                 ...            ...
# 4113                   2                   3              5
# 4114                  10                   5              5
# 4115                   6                   1             13
# 4116                   9                   9              7
# 4117                  10                   5              5
#
#       club_main_category_id(target)
# 0                                13
# 1                                13
# 2                                13
# 3                                13
# 4                                13
# ...                             ...
# 4113                              5
# 4114                              5
# 4115                              5
# 4116                              5
# 4117                              5
#
# [4118 rows x 4 columns]

# %%
pre_t_df.describe().T
# Out:
#                                 count      mean       std  min  25%  50%  75%  \
# user_like_category             4118.0  6.564594  3.526034  1.0  4.0  6.0  9.0
# wish_list_category             4118.0  6.577708  3.624353  1.0  3.0  7.0  9.0
# user_category                  4118.0  5.440262  3.161540  1.0  3.0  6.0  8.0
# club_main_category_id(target)  4118.0  5.353084  2.962752  1.0  3.0  6.0  8.0
#
#                                 max
# user_like_category             13.0
# wish_list_category             13.0
# user_category                  13.0
# club_main_category_id(target)  13.0

# %%
pre_t_df.hist()
# Out:
# array([[<Axes: title={'center': 'user_like_category'}>,
#         <Axes: title={'center': 'wish_list_category'}>],
#        [<Axes: title={'center': 'user_category'}>,
#         <Axes: title={'center': 'club_main_category_id(target)'}>]],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features.values, targets.values, stratify=targets, test_size= 0.2, random_state=321)

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 결정트리 이미지 확인 후 dtc 의 최초 파라미터 확인
from sklearn.metrics import accuracy_score
print(dtc.max_depth)
print(dtc.min_samples_split)
print(dtc.feature_importances_)

# 교차 검증 이전 정확도 확인
prediction = dtc.predict(X_test)
acc_score = accuracy_score(y_test, prediction)
print('='* 50)
print(f"\n최초 정확도: {round(acc_score * 100,2)} %")
# Out:
# None
# 2
# [0.13647014 0.14685527 0.71667459]
# ==================================================
#
# 최초 정확도: 63.35 %

# %%
# 교차 검증 진행 GridSearchCV
from sklearn.model_selection import GridSearchCV

parameters = {
    'max_depth': [5, 7, 9 ,10],
    'min_samples_split': [10, 20 ,30] 
}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=3, refit=True, return_train_score=True)
g_dtc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 7, 9, 10],
#                          'min_samples_split': [10, 20, 30]},
#              return_train_score=True)

# %% [markdown]
# #### 위 아래 이미지 추가

# %%
# 교차 검증 이후 정확도 확인 
print(g_dtc.best_params_, g_dtc.best_score_, sep='\n')
dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

acc_score = accuracy_score(y_test, prediction)
print('='* 50)
print(f"\n교차검증 이후 정확도: {round(acc_score * 100,2)} %")
# Out:
# {'max_depth': 7, 'min_samples_split': 30}
# 0.7246508803885853
# ==================================================
#
# 교차검증 이후 정확도: 74.03 %

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='micro')
    recall = recall_score(y_test , prediction, average='micro')
    f1 = f1_score(y_test, prediction, average='micro')
    # auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,8))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %% [markdown]
# #### 아래 이미지 추가

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[ 95   6   5   1   5   3   2   3   6]
#  [  0  27   0   2   2   3   2   0   0]
#  [  3   5  64   2   4   2   2   3   3]
#  [  1   1   0  69   3   2   4   2   2]
#  [  2   2   3   2  43   1   0   3   4]
#  [  6   2   2   2   4  72   2   3   5]
#  [  3   5   1   3   2   5  90   6   5]
#  [ 12   4   6   8   3   6   4 129   2]
#  [  2   1   1   2   1   0   3   7  21]]
# 정확도: 0.7403, 정밀도: 0.7403, 재현율: 0.7403, F1: 0.7403
# ################################################################################

# %%
# parameters = {
#     'C': [10, 100, 1000, 10000],
#     'gamma': [10, 100, 1000],
#     'kernel': ['linear']
# }

# svc = SVC(probability=True)

# g_svc = GridSearchCV(svc, param_grid=parameters, cv=3, refit=True, return_train_score=True)
# g_svc.fit(X_train, y_train)

# %%
# svc = g_svc.best_estimator_
# prediction = g_svc.predict(X_test)

# %%
# get_evaluation(y_test, prediction, svc, X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_c = KNeighborsClassifier()

parameters = {
    'n_neighbors' : [3, 5, 7, 9, 11]
}

g_knn_c = GridSearchCV(knn_c, param_grid=parameters, cv=3, refit=True, return_train_score=True)
g_knn_c.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %% [markdown]
# #### 이미지 추가

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[ 96   4   5   3   3   3   4   1   7]
#  [ 18   7   2   3   1   3   2   0   0]
#  [ 12   0  58   4   4   3   1   2   4]
#  [  1   1   7  61   5   2   4   1   2]
#  [  5   0   4   7  34   3   0   4   3]
#  [  7   1   2   2   6  66   7   2   5]
#  [  8   1   1   4   1  11  83   7   4]
#  [ 15   1   6   9   4   3  15 119   2]
#  [  3   1   3   2   1   1   4   0  23]]
# 정확도: 0.6638, 정밀도: 0.6638, 재현율: 0.6638, F1: 0.6638
# ################################################################################

# %%
# 데이터의 훈련 시 시간이 얼마나 걸릴 지 모르기 때문에 우선 1부터 조금씩 낮아지도록 훈련 진행
from sklearn.ensemble import AdaBoostClassifier

parameters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.7, 0.8, 0.9, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid= parameters, cv=3, refit=True, return_train_score=True, n_jobs = -1)

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[ 96   4   5   3   3   3   4   1   7]
#  [ 18   7   2   3   1   3   2   0   0]
#  [ 12   0  58   4   4   3   1   2   4]
#  [  1   1   7  61   5   2   4   1   2]
#  [  5   0   4   7  34   3   0   4   3]
#  [  7   1   2   2   6  66   7   2   5]
#  [  8   1   1   4   1  11  83   7   4]
#  [ 15   1   6   9   4   3  15 119   2]
#  [  3   1   3   2   1   1   4   0  23]]
# 정확도: 0.6638, 정밀도: 0.6638, 재현율: 0.6638, F1: 0.6638
# ################################################################################

# %%
features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features.values, targets.values, stratify=targets, test_size= 0.2, random_state=321)

# 검증데이터 분류
X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=321 )

# %%
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'max_depth' : [8, 9, 10],
    'min_samples_split' : [50, 100, 150]
}

rfc = RandomForestClassifier(n_estimators=70)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=3, n_jobs= -1)

# %%
g_rfc.fit(X_val_train, y_val_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=70), n_jobs=-1,
#              param_grid={'max_depth': [8, 9, 10],
#                          'min_samples_split': [50, 100, 150]})

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_val_test)

# %%
get_evaluation(y_val_test, prediction, rfc, X_val_test)
# Out:
# 오차 행렬
# [[ 69   0   6   6   0   2   4  11   2]
#  [  0   1  20   2   0   3   2   0   1]
#  [  6   0  44   8   1   6   0   5   1]
#  [  2   0   5  44   0   7   3   5   1]
#  [  2   0   5  15  16   5   2   3   0]
#  [  4   0   5   2   2  56   2   4   4]
#  [  4   0   5   8   1   3  69   6   0]
#  [  7   0  10   8   0   5   3 102   4]
#  [  0   0   0   1   0   2   0  20   7]]
# 정확도: 0.6191, 정밀도: 0.6191, 재현율: 0.6191, F1: 0.6191
# ################################################################################

# %%
g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=70), n_jobs=-1,
#              param_grid={'max_depth': [8, 9, 10],
#                          'min_samples_split': [50, 100, 150]})

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[ 95   0  11   4   2   3   2   8   1]
#  [  0   0  25   4   2   3   2   0   0]
#  [  3   1  66   6   2   2   2   3   3]
#  [  2   0   2  67   3   2   4   2   2]
#  [  2   0   6  13  29   3   0   4   3]
#  [  6   0   4   4   2  72   2   5   3]
#  [  3   1   5   5   0   5  90   7   4]
#  [ 12   0   9  10   2   6   4 130   1]
#  [  2   0   2   2   1   0   3  15  13]]
# 정확도: 0.6820, 정밀도: 0.6820, 재현율: 0.6820, F1: 0.6820
# ################################################################################

# %%
proba = rfc.predict_proba(X_test)
prediction = rfc.predict(X_test)


class_labels = rfc.classes_

# proba 및 predict 출력
for proba, predict in zip(proba.tolist(), prediction.tolist()):
    print("Predicted class:", predict)
    print("Class probabilities:", {label: p for label, p in zip(class_labels, proba)})
    print()  # 빈 줄 추가
# Out:
# Predicted class: 4
# Class probabilities: {1: 0.12132480905349859, 2: 0.10770675953437579, 3: 0.1387687224089633, 4: 0.16172679814597868, 5: 0.12187912331596572, 6: 0.1404520061865262, 7: 0.10060563642217112, 8: 0.07711598280162825, 13: 0.030420162130892305}
#
# Predicted class: 8
# Class probabilities: {1: 0.05093495959110849, 2: 0.006752930578260491, 3: 0.013912019354042333, 4: 0.011251333014102596, 5: 0.03592995972630867, 6: 0.03878930892602246, 7: 0.0911840197605371, 8: 0.672481750702864, 13: 0.07876371834675396}
#
# Predicted class: 8
# Class probabilities: {1: 0.026719675264840807, 2: 0.01524996458670168, 3: 0.037017984721852235, 4: 0.022894728795143548, 5: 0.0358034481134167, 6: 0.04576442227209793, 7: 0.02485230800726773, 8: 0.7212931210723033, 13: 0.07040434716637602}
#
# Predicted class: 4
# Class probabilities: {1: 0.05647124467457316, 2: 0.06895148656297286, 3: 0.16059525337185757, 4: 0.255177208442692, 5: 0.12761587069451474, 6: 0.17041687816502585, 7: 0.06727131987214935, 8: 0.06251278374919446, 13: 0.030987954467019956}
#
# Predicted class: 8
# Class probabilities: {1: 0.0422085098754417, 2: 0.006714236991151271, 3: 0.011130353595117572, 4: 0.016744027299736803, 5: 0.03678496911040433, 6: 0.03860048427605369, 7: 0.07315726585557202, 8: 0.6824561353890705, 13: 0.0922040176074523}
#
# Predicted class: 8
# Class probabilities: {1: 0.033591106356121433, 2: 0.012465965819372973, 3: 0.0227328555805324, 4: 0.021874621496669557, 5: 0.02673227798452872, 6: 0.0301642151607815, 7: 0.05051517687173219, 8: 0.766054616280142, 13: 0.03586916445011934}
#
# Predicted class: 4
# Class probabilities: {1: 0.12032930768418611, 2: 0.08105627912816313, 3: 0.1534971186667061, 4: 0.30136384481797757, 5: 0.10452113751591326, 6: 0.10006168972169978, 7: 0.06675811172268677, 8: 0.05985869675127326, 13: 0.012553813991394115}
#
# Predicted class: 1
# Class probabilities: {1: 0.5125154052734296, 2: 0.04445028845452536, 3: 0.10064137988481314, 4: 0.058653951720052354, 5: 0.046929694269683166, 6: 0.07979259588052827, 7: 0.10901352691488707, 8: 0.04169361624520256, 13: 0.006309541356878525}
#
# Predicted class: 8
# Class probabilities: {1: 0.04289427393604046, 2: 0.0044195972449271575, 3: 0.011947186193791384, 4: 0.008393375383199413, 5: 0.029405593773166927, 6: 0.03113137919542914, 7: 0.087678504300174, 8: 0.6959471170822416, 13: 0.08818297289103005}
#
# Predicted class: 6
# Class probabilities: {1: 0.03824396605732199, 2: 0.054170321122650834, 3: 0.14024613113842138, 4: 0.14103283524901208, 5: 0.09523375725932659, 6: 0.35782497110402334, 7: 0.06277319870069431, 8: 0.06770205266581436, 13: 0.0427727667027349}
#
# Predicted class: 3
# Class probabilities: {1: 0.12624828542537206, 2: 0.14167757028025083, 3: 0.19929363330078453, 4: 0.12540701646264296, 5: 0.14952385190180942, 6: 0.06440572904866082, 7: 0.1009099758801993, 8: 0.08232845697639324, 13: 0.010205480723886884}
#
# Predicted class: 8
# Class probabilities: {1: 0.04975828416055421, 2: 0.00713671312301405, 3: 0.04019225052996746, 4: 0.02593522411182177, 5: 0.04458167781870747, 6: 0.029568916850660175, 7: 0.04375230999878432, 8: 0.7271444832352406, 13: 0.03193014017125032}
#
# Predicted class: 3
# Class probabilities: {1: 0.08104528495991146, 2: 0.1322330423148173, 3: 0.2867776574727974, 4: 0.12692403336820154, 5: 0.06527714204364539, 6: 0.16418271687152716, 7: 0.05159814249444792, 8: 0.06720268158115078, 13: 0.024759298893501182}
#
# Predicted class: 7
# Class probabilities: {1: 0.09647051616526564, 2: 0.015210502657197906, 3: 0.09448953395385978, 4: 0.055236181820657794, 5: 0.07065555539560335, 6: 0.06975862061462619, 7: 0.5200572942490684, 8: 0.0578475127309422, 13: 0.020274282412778743}
#
# Predicted class: 8
# Class probabilities: {1: 0.04652077526205575, 2: 0.0032381608857908637, 3: 0.024163198716980052, 4: 0.01990894942552495, 5: 0.02793134592502091, 6: 0.017888230494949316, 7: 0.053222143761225006, 8: 0.7806289277169642, 13: 0.026498267811489222}
#
# Predicted class: 8
# Class probabilities: {1: 0.048448920912158376, 2: 0.0033959899749373434, 3: 0.052433942516233255, 4: 0.01549298688382592, 5: 0.011989485001394065, 6: 0.015356178728030913, 7: 0.011521807589580678, 8: 0.8019723709817401, 13: 0.039388317412099215}
#
# Predicted class: 4
# Class probabilities: {1: 0.09561927459096393, 2: 0.07424779695658919, 3: 0.10608567517636398, 4: 0.2499492435969423, 5: 0.2165385419472557, 6: 0.08283192819656343, 7: 0.08440857817565019, 8: 0.07294048376451596, 13: 0.017378477595155265}
#
# Predicted class: 1
# Class probabilities: {1: 0.6022968341920524, 2: 0.027775418233081755, 3: 0.06446419118178395, 4: 0.043876766091568875, 5: 0.047888860329779535, 6: 0.07152535768579531, 7: 0.03906761780217955, 8: 0.08279337762947249, 13: 0.02031157685428603}
#
# Predicted class: 3
# Class probabilities: {1: 0.12964145870742624, 2: 0.09101536890611166, 3: 0.33222496689912967, 4: 0.15284446342008945, 5: 0.07149199436174077, 6: 0.06413791952628196, 7: 0.0641999043691086, 8: 0.08210948723558979, 13: 0.01233443657452187}
#
# Predicted class: 8
# Class probabilities: {1: 0.0672610394999146, 2: 0.017635077546277203, 3: 0.06623885278654791, 4: 0.03090524307515421, 5: 0.03683604554571476, 6: 0.04704414060462688, 7: 0.14528998853749645, 8: 0.5375335754508646, 13: 0.05125603695340337}
#
# Predicted class: 4
# Class probabilities: {1: 0.068342487205659, 2: 0.04774071859442069, 3: 0.1789231531363653, 4: 0.24159610769968495, 5: 0.12856305751607577, 6: 0.1036445860510645, 7: 0.11306396599504344, 8: 0.10685046114141615, 13: 0.011275462660270116}
#
# Predicted class: 13
# Class probabilities: {1: 0.07880995115808154, 2: 0.01559680097991004, 3: 0.07534210764268164, 4: 0.051990214336144036, 5: 0.031363856697828665, 6: 0.032165156599768784, 7: 0.09474105363401943, 8: 0.2764767239797991, 13: 0.3435141349717668}
#
# Predicted class: 4
# Class probabilities: {1: 0.10482662159435097, 2: 0.0837074001181724, 3: 0.10564214066472455, 4: 0.271101653646679, 5: 0.14518492354686316, 6: 0.1246216516299102, 7: 0.07112354400569794, 8: 0.06749701284739304, 13: 0.02629505194620877}
#
# Predicted class: 8
# Class probabilities: {1: 0.04324537245635597, 2: 0.002181038573627717, 3: 0.02579902623432513, 4: 0.011136568533278046, 5: 0.025545719951534134, 6: 0.027620235516502882, 7: 0.05672966952374046, 8: 0.7565555922971606, 13: 0.05118677691347493}
#
# Predicted class: 8
# Class probabilities: {1: 0.05410264477920774, 2: 0.005606614132888899, 3: 0.042380836314335445, 4: 0.03189857292946002, 5: 0.020502341689509714, 6: 0.03849753740656795, 7: 0.028399279908018087, 8: 0.7464171586309076, 13: 0.03219501420910448}
#
# Predicted class: 8
# Class probabilities: {1: 0.05193170314931935, 2: 0.014848307127155175, 3: 0.017316275402120065, 4: 0.048257079999431254, 5: 0.01711062521883453, 6: 0.02674173182681373, 7: 0.04724932623537212, 8: 0.6881839914426987, 13: 0.0883609595982548}
#
# Predicted class: 6
# Class probabilities: {1: 0.09593435742982137, 2: 0.029874883740422443, 3: 0.07868447949773935, 4: 0.1189676036796541, 5: 0.06894383459880155, 6: 0.4568428209943065, 7: 0.0926257677181889, 8: 0.0535269241973411, 13: 0.0045993281437248425}
#
# Predicted class: 8
# Class probabilities: {1: 0.014603172057529815, 2: 0.014070018074889869, 3: 0.026463046582507827, 4: 0.019465175153665377, 5: 0.040283426271776446, 6: 0.056939743428542126, 7: 0.05087972160200953, 8: 0.7131891670948852, 13: 0.06410652973419381}
#
# Predicted class: 1
# Class probabilities: {1: 0.5563079993037298, 2: 0.03124528846168776, 3: 0.08228259591464314, 4: 0.03634593128649813, 5: 0.052929888077616505, 6: 0.07804216792524107, 7: 0.06819140772997936, 8: 0.09269230671748763, 13: 0.001962414583116699}
#
# Predicted class: 6
# Class probabilities: {1: 0.07736233584743413, 2: 0.043050462043024144, 3: 0.04398391810298672, 4: 0.07536207109871355, 5: 0.12321404154557498, 6: 0.39429815480103947, 7: 0.12176447549380787, 8: 0.09502121583872539, 13: 0.02594332522869364}
#
# Predicted class: 1
# Class probabilities: {1: 0.7511317267418194, 2: 0.0050531325620391645, 3: 0.06132078373536069, 4: 0.04815922255122962, 5: 0.03884287793807772, 6: 0.01922042788337352, 7: 0.042307074103983565, 8: 0.0286417169832597, 13: 0.005323037500856489}
#
# Predicted class: 4
# Class probabilities: {1: 0.08764959921709237, 2: 0.08934914729006797, 3: 0.10139067827201997, 4: 0.2154528567238889, 5: 0.17164832217710518, 6: 0.14454581663489122, 7: 0.0812370234275848, 8: 0.08509179245047359, 13: 0.02363476380687612}
#
# Predicted class: 3
# Class probabilities: {1: 0.14847355323672481, 2: 0.10656000954138375, 3: 0.25995783347607543, 4: 0.1033586578237073, 5: 0.11290626542274239, 6: 0.15628658953686184, 7: 0.04624299996914085, 8: 0.052951282664736005, 13: 0.013262808328627734}
#
# Predicted class: 7
# Class probabilities: {1: 0.07229180058005953, 2: 0.03736193149892697, 3: 0.058533842150327635, 4: 0.0567968794642014, 5: 0.03503079499123301, 6: 0.09246128342771008, 7: 0.5625763483297372, 8: 0.07261961982275592, 13: 0.012327499735048219}
#
# Predicted class: 4
# Class probabilities: {1: 0.12048370038150161, 2: 0.05028030966503623, 3: 0.1703333553246249, 4: 0.2218657374008802, 5: 0.1517785422671742, 6: 0.10326582318474516, 7: 0.09185995103526153, 8: 0.07833099481784965, 13: 0.011801585922926489}
#
# Predicted class: 7
# Class probabilities: {1: 0.015696173424188234, 2: 0.01845895295246681, 3: 0.029560540780360096, 4: 0.02644146663984012, 5: 0.060637733846811086, 6: 0.035015010890397075, 7: 0.732278730380744, 8: 0.07185194716256287, 13: 0.010059443922629918}
#
# Predicted class: 1
# Class probabilities: {1: 0.5448031484175629, 2: 0.04183086881898468, 3: 0.15747637187749186, 4: 0.042900818165723026, 5: 0.023099161873978303, 6: 0.04245725575710921, 7: 0.043564717349688704, 8: 0.10070627192146042, 13: 0.0031613858180007753}
#
# Predicted class: 1
# Class probabilities: {1: 0.5910011942320922, 2: 0.039461124434127304, 3: 0.06651653370136063, 4: 0.04608582638826751, 5: 0.05734387505281643, 6: 0.07697032400444023, 7: 0.06595094947695977, 8: 0.05103602989558342, 13: 0.005634142814352445}
#
# Predicted class: 3
# Class probabilities: {1: 0.14222166550482604, 2: 0.09186654568180527, 3: 0.24975453206639, 4: 0.15095535201763488, 5: 0.08712347585354953, 6: 0.09128200582156923, 7: 0.07833352946855805, 8: 0.06974513785344802, 13: 0.03871775573221908}
#
# Predicted class: 1
# Class probabilities: {1: 0.7120367424697949, 2: 0.05038594716395633, 3: 0.061343554374183845, 4: 0.027314653550077367, 5: 0.009087080708025897, 6: 0.04983918789814759, 7: 0.0324364914026228, 8: 0.04780687967613002, 13: 0.009749462757061254}
#
# Predicted class: 3
# Class probabilities: {1: 0.08233665518016282, 2: 0.0970748099710153, 3: 0.35543489065791944, 4: 0.14386152291300644, 5: 0.0836280926560737, 6: 0.08752219092220419, 7: 0.06348448154614053, 8: 0.07564685357418259, 13: 0.011010502579294975}
#
# Predicted class: 4
# Class probabilities: {1: 0.13786848031295307, 2: 0.10462044459371624, 3: 0.20378759573080552, 4: 0.23192001440546173, 5: 0.08655946433843702, 6: 0.06286161589951345, 7: 0.07683718121115556, 8: 0.07795908713103686, 13: 0.017586116376920546}
#
# Predicted class: 6
# Class probabilities: {1: 0.0554273644480492, 2: 0.021431340244737744, 3: 0.05795148021578981, 4: 0.12107536498361969, 5: 0.08348897897303699, 6: 0.5081414495728881, 7: 0.04611001669768238, 8: 0.0846604537454996, 13: 0.02171355111869659}
#
# Predicted class: 4
# Class probabilities: {1: 0.10243240434664988, 2: 0.07727009964480258, 3: 0.15227974436324782, 4: 0.23375129841225167, 5: 0.16147679979852142, 6: 0.15209644799329824, 7: 0.060747594633481734, 8: 0.045047641696182125, 13: 0.01489796911156445}
#
# Predicted class: 3
# Class probabilities: {1: 0.12788239338936816, 2: 0.05850791453881799, 3: 0.1922939490601536, 4: 0.18347921613737334, 5: 0.1520483451192238, 6: 0.10070782303676915, 7: 0.08010355001515114, 8: 0.09000054005724893, 13: 0.014976268645893976}
#
# Predicted class: 3
# Class probabilities: {1: 0.11412529748675782, 2: 0.13927236099987816, 3: 0.20004001849392763, 4: 0.1586375764374458, 5: 0.09721015710861564, 6: 0.098819399837092, 7: 0.06326960977190176, 8: 0.10216990315408879, 13: 0.026455676710292263}
#
# Predicted class: 3
# Class probabilities: {1: 0.1606526866940563, 2: 0.14384252357179478, 3: 0.1956502234059371, 4: 0.1471697671985542, 5: 0.0756513891401671, 6: 0.0910162750952393, 7: 0.069517003107714, 8: 0.08011451770743365, 13: 0.036385614079103526}
#
# Predicted class: 8
# Class probabilities: {1: 0.04531470305677712, 2: 0.011287593202012362, 3: 0.01950477500026764, 4: 0.04150230966690135, 5: 0.010543241728488618, 6: 0.022970391324743496, 7: 0.0665052161342806, 8: 0.6885408187766129, 13: 0.09383095110991575}
#
# Predicted class: 7
# Class probabilities: {1: 0.060509951376750706, 2: 0.015090627594156799, 3: 0.051362232994584534, 4: 0.061887421399843996, 5: 0.031145796014342197, 6: 0.06450353676321194, 7: 0.6164978597295289, 8: 0.08550422445867585, 13: 0.013498349668905068}
#
# Predicted class: 3
# Class probabilities: {1: 0.1292186456779771, 2: 0.1266252668170817, 3: 0.21581266752241585, 4: 0.1478140830772335, 5: 0.08827058806085122, 6: 0.09399839303328592, 7: 0.0826123674162012, 8: 0.08529778472829072, 13: 0.030350203666662714}
#
# Predicted class: 5
# Class probabilities: {1: 0.07329108602937207, 2: 0.06131298333223835, 3: 0.16169860930698443, 4: 0.1772823661589684, 5: 0.18836460774122954, 6: 0.1784665187455094, 7: 0.09569767556288936, 8: 0.05148927894351799, 13: 0.0123968741792906}
#
# Predicted class: 1
# Class probabilities: {1: 0.756450964414952, 2: 0.021574224358254852, 3: 0.0503732651483589, 4: 0.03252948190447714, 5: 0.03560449954029483, 6: 0.021782217537826117, 7: 0.05548786771894964, 8: 0.024803025481669853, 13: 0.0013944538952166598}
#
# Predicted class: 4
# Class probabilities: {1: 0.09851619799305229, 2: 0.06509371523176048, 3: 0.21934230687463105, 4: 0.23339883378812445, 5: 0.1216520655783901, 6: 0.09935491682556277, 7: 0.07603051477398087, 8: 0.078125433251262, 13: 0.008486015683236025}
#
# Predicted class: 4
# Class probabilities: {1: 0.1352060832008118, 2: 0.04452637468433783, 3: 0.16278115501228038, 4: 0.22700615219717482, 5: 0.1498616966451977, 6: 0.1161695838256509, 7: 0.07976176846939707, 8: 0.07338823407677421, 13: 0.011298951888375158}
#
# Predicted class: 8
# Class probabilities: {1: 0.07570882891217633, 2: 0.03603843830926866, 3: 0.03924415156472163, 4: 0.07466737114330588, 5: 0.037539037137619136, 6: 0.036617802482341213, 7: 0.11640510086423483, 8: 0.31029877129829864, 13: 0.2734804982880338}
#
# Predicted class: 1
# Class probabilities: {1: 0.5923704533646222, 2: 0.02656322090736346, 3: 0.12449856871900304, 4: 0.025828184633596634, 5: 0.04848349255046384, 6: 0.03931488029371701, 7: 0.08104823373529263, 8: 0.051872978033196016, 13: 0.010019987762745184}
#
# Predicted class: 3
# Class probabilities: {1: 0.09455153575197174, 2: 0.07734663730471947, 3: 0.3761586314405701, 4: 0.12118067617252787, 5: 0.052407621893673574, 6: 0.11768881697690625, 7: 0.06495011391230451, 8: 0.08157385904330408, 13: 0.014142107504022347}
#
# Predicted class: 6
# Class probabilities: {1: 0.08385709888980405, 2: 0.019423309065268346, 3: 0.05671564978400313, 4: 0.08849992540207187, 5: 0.0813522700601339, 6: 0.44655270062375996, 7: 0.12819336111406915, 8: 0.07606422697157181, 13: 0.019341458089317698}
#
# Predicted class: 1
# Class probabilities: {1: 0.6731023134028261, 2: 0.03338509996086969, 3: 0.0357247426875528, 4: 0.043881685381113394, 5: 0.055221380877391396, 6: 0.06597098635518048, 7: 0.03407457657390174, 8: 0.05462973913245985, 13: 0.004009475628704414}
#
# Predicted class: 6
# Class probabilities: {1: 0.08378530603504454, 2: 0.02938064051653324, 3: 0.07079174916242137, 4: 0.1712233287495331, 5: 0.09188644003017737, 6: 0.4191102472504914, 7: 0.04285669820283038, 8: 0.0784533245849319, 13: 0.01251226546803666}
#
# Predicted class: 8
# Class probabilities: {1: 0.05309244897321494, 2: 0.005799236070675487, 3: 0.021718452265779887, 4: 0.01915144441472718, 5: 0.02899056919064952, 6: 0.07492287709822941, 7: 0.04721270973866631, 8: 0.686821271661067, 13: 0.06229099058699023}
#
# Predicted class: 4
# Class probabilities: {1: 0.10180289098414819, 2: 0.06863615322508693, 3: 0.20238038586117124, 4: 0.2650229765299401, 5: 0.1086438550669435, 6: 0.09417459007370198, 7: 0.06980562990629846, 8: 0.07618097115091996, 13: 0.013352547201789649}
#
# Predicted class: 6
# Class probabilities: {1: 0.0804077026697025, 2: 0.03851182115719668, 3: 0.03612163946477455, 4: 0.08217159452218878, 5: 0.10481210087444523, 6: 0.4693921828489937, 7: 0.10614773043855719, 8: 0.05556916362225217, 13: 0.026866064401889253}
#
# Predicted class: 3
# Class probabilities: {1: 0.1110539722279984, 2: 0.07601903741454057, 3: 0.32542350365606915, 4: 0.12974879975973852, 5: 0.09043347356278064, 6: 0.1453487833414168, 7: 0.03565413978279107, 8: 0.072213929134026, 13: 0.014104361120638795}
#
# Predicted class: 8
# Class probabilities: {1: 0.026412362338872668, 2: 0.01752251685607778, 3: 0.026368683497008993, 4: 0.023978574842606872, 5: 0.03030766417388202, 6: 0.021167040927614372, 7: 0.1295302144139527, 8: 0.6923816495136097, 13: 0.03233129343637484}
#
# Predicted class: 1
# Class probabilities: {1: 0.5189836400926143, 2: 0.04005637249399556, 3: 0.11584109465944142, 4: 0.05458713615830494, 5: 0.046774266569438366, 6: 0.043562859001242966, 7: 0.07322848232789453, 8: 0.09945049289105103, 13: 0.007515655806016759}
#
# Predicted class: 4
# Class probabilities: {1: 0.06715955304793725, 2: 0.06867897842252489, 3: 0.13707228756776121, 4: 0.2468908625702314, 5: 0.18706787240630884, 6: 0.1301231279315184, 7: 0.07332825987555436, 8: 0.05950949173372705, 13: 0.03016956644443655}
#
# Predicted class: 7
# Class probabilities: {1: 0.06180478946043543, 2: 0.05228797080210504, 3: 0.09012009234409459, 4: 0.042426790499567296, 5: 0.044806205254959215, 6: 0.2110881800079581, 7: 0.38818019011137983, 8: 0.09059044312245956, 13: 0.018695338397040958}
#
# Predicted class: 3
# Class probabilities: {1: 0.11579930703333526, 2: 0.17293992117818177, 3: 0.2473327119343292, 4: 0.1481840448445539, 5: 0.07449547914498351, 6: 0.1278309891264972, 7: 0.03974584845173185, 8: 0.049051773904714234, 13: 0.02461992438167321}
#
# Predicted class: 8
# Class probabilities: {1: 0.07195747860562846, 2: 0.023589236222043508, 3: 0.029271440213367306, 4: 0.043963316856409446, 5: 0.021544780925484924, 6: 0.051145210671132514, 7: 0.09814271468039737, 8: 0.5761455772970685, 13: 0.08424024452846801}
#
# Predicted class: 4
# Class probabilities: {1: 0.10243240434664988, 2: 0.07727009964480258, 3: 0.15227974436324782, 4: 0.23375129841225167, 5: 0.16147679979852142, 6: 0.15209644799329824, 7: 0.060747594633481734, 8: 0.045047641696182125, 13: 0.01489796911156445}
#
# Predicted class: 5
# Class probabilities: {1: 0.09810940548709525, 2: 0.05938550992755943, 3: 0.1771080843247407, 4: 0.1829836768285752, 5: 0.20589210098827382, 6: 0.10049944671380273, 7: 0.07631632214913775, 8: 0.08547435148037595, 13: 0.01423110210043905}
#
# Predicted class: 8
# Class probabilities: {1: 0.04009868096858187, 2: 0.018469127313302754, 3: 0.0422281510450633, 4: 0.04134986885397833, 5: 0.04822352633562981, 6: 0.06591908678889051, 7: 0.07614251887026484, 8: 0.3707567288895068, 13: 0.2968123109347816}
#
# Predicted class: 13
# Class probabilities: {1: 0.0509643737360281, 2: 0.016693425133564973, 3: 0.027064832793009936, 4: 0.051387189935031476, 5: 0.009871694659080648, 6: 0.08139255720723544, 7: 0.05449803404695549, 8: 0.3321055047725268, 13: 0.37602238771656726}
#
# Predicted class: 1
# Class probabilities: {1: 0.46469875407713335, 2: 0.03595505702904468, 3: 0.09155039613606668, 4: 0.1036807056791784, 5: 0.048423588269299905, 6: 0.09451671074251188, 7: 0.09062438162409844, 8: 0.051145025391898954, 13: 0.01940538105076771}
#
# Predicted class: 6
# Class probabilities: {1: 0.08139867026518367, 2: 0.07202979680369283, 3: 0.07624178907334943, 4: 0.05941132394672571, 5: 0.11576120112373925, 6: 0.3493606291088441, 7: 0.14648915798435447, 8: 0.0856376430694121, 13: 0.01366978862469851}
#
# Predicted class: 1
# Class probabilities: {1: 0.7952107653749969, 2: 0.011674778564028425, 3: 0.05010263682195678, 4: 0.02314249453051126, 5: 0.02794722160541296, 6: 0.019661495386624896, 7: 0.016269502981209785, 8: 0.0524239076444043, 13: 0.0035671970908543}
#
# Predicted class: 6
# Class probabilities: {1: 0.0837155452655377, 2: 0.03649224622609453, 3: 0.0559388070411669, 4: 0.08800645568589953, 5: 0.06888730580010723, 6: 0.5443909517643657, 7: 0.04320087175732246, 8: 0.05442728029148797, 13: 0.02494053616801789}
#
# Predicted class: 4
# Class probabilities: {1: 0.10210998984684412, 2: 0.041132330435470425, 3: 0.14052167045589048, 4: 0.32560278443152846, 5: 0.1278708957566738, 6: 0.08512049293847822, 7: 0.09271037289388816, 8: 0.07800073918493411, 13: 0.0069307240562923944}
#
# Predicted class: 6
# Class probabilities: {1: 0.1029483499577194, 2: 0.038063343722871755, 3: 0.0733649575392572, 4: 0.13251744375842592, 5: 0.061648850475181885, 6: 0.42307470914442064, 7: 0.08070865830182734, 8: 0.07218986513090858, 13: 0.015483821969387383}
#
# Predicted class: 1
# Class probabilities: {1: 0.6017935705734732, 2: 0.03772375565001129, 3: 0.0830243879940482, 4: 0.05528227441786182, 5: 0.032224396270835926, 6: 0.05722492459852262, 7: 0.03145231986033782, 8: 0.0922160461365508, 13: 0.009058324498358144}
#
# Predicted class: 5
# Class probabilities: {1: 0.09159120473662737, 2: 0.05909535911140453, 3: 0.08166759443233948, 4: 0.1396476689425149, 5: 0.35152571644271424, 6: 0.0989474036137898, 7: 0.08576322958349643, 8: 0.073663499149249, 13: 0.018098323987864023}
#
# Predicted class: 7
# Class probabilities: {1: 0.03869841026483858, 2: 0.021881099230047725, 3: 0.05469332323986287, 4: 0.09207657183695858, 5: 0.0608555159836336, 6: 0.06455715345152473, 7: 0.5872513494193058, 8: 0.07190654867447444, 13: 0.008080027899353812}
#
# Predicted class: 6
# Class probabilities: {1: 0.0848604657578675, 2: 0.0328124951225781, 3: 0.043670295600031106, 4: 0.07114652447957871, 5: 0.08574350444065414, 6: 0.4922746536400322, 7: 0.12089222875116454, 8: 0.05833231872151524, 13: 0.010267513486578367}
#
# Predicted class: 4
# Class probabilities: {1: 0.09577458183951511, 2: 0.05114187505362862, 3: 0.12715174878966917, 4: 0.31692826716803335, 5: 0.13147746955146922, 6: 0.10206762479878884, 7: 0.0548485952285794, 8: 0.08588633232384595, 13: 0.03472350524647024}
#
# Predicted class: 4
# Class probabilities: {1: 0.06979327497192434, 2: 0.08910445257154023, 3: 0.18252981902999757, 4: 0.25055872789974654, 5: 0.11357990504350342, 6: 0.06504792684535732, 7: 0.07680344047852374, 8: 0.1355888068002525, 13: 0.016993646359154048}
#
# Predicted class: 3
# Class probabilities: {1: 0.09697696103907427, 2: 0.14914744415799588, 3: 0.31572885823925395, 4: 0.12657783745382245, 5: 0.045648640207708244, 6: 0.07122205107680425, 7: 0.08195166391155871, 8: 0.10745075559562499, 13: 0.0052957883181572385}
#
# Predicted class: 3
# Class probabilities: {1: 0.0740685339573025, 2: 0.11622044537892494, 3: 0.29782386647850917, 4: 0.13609499157041194, 5: 0.096090860941095, 6: 0.14953166407674645, 7: 0.03720764671793937, 8: 0.07353174686202253, 13: 0.01943024401704801}
#
# Predicted class: 8
# Class probabilities: {1: 0.04122970607229261, 2: 0.004183381067221111, 3: 0.03310034884135376, 4: 0.0432800825096708, 5: 0.022503020128709136, 6: 0.01752267307637578, 7: 0.01801558259735467, 8: 0.7834469445929989, 13: 0.036718261114023244}
#
# Predicted class: 1
# Class probabilities: {1: 0.7166007217513132, 2: 0.030094873611012624, 3: 0.05249977104092585, 4: 0.03374772763208438, 5: 0.023348580451561546, 6: 0.05839613144229466, 7: 0.02957759557497135, 8: 0.051890238740285866, 13: 0.0038443597555502694}
#
# Predicted class: 3
# Class probabilities: {1: 0.06899500363550838, 2: 0.12822738825566724, 3: 0.286376450741203, 4: 0.1366824526591528, 5: 0.07775762286817986, 6: 0.15200195334899544, 7: 0.0647400334291243, 8: 0.05686530976960982, 13: 0.02835378529255918}
#
# Predicted class: 3
# Class probabilities: {1: 0.10188939904702456, 2: 0.0824750989711647, 3: 0.34381727338956475, 4: 0.11580463708724323, 5: 0.07682532442422388, 6: 0.1497374349533828, 7: 0.07101295763289119, 8: 0.04134555214233159, 13: 0.01709232235217312}
#
# Predicted class: 1
# Class probabilities: {1: 0.4712466792979213, 2: 0.05116490391109359, 3: 0.11108273424679292, 4: 0.07318548271104286, 5: 0.054098064490241696, 6: 0.080278018891694, 7: 0.10350574436438939, 8: 0.04955481018725005, 13: 0.005883561899574226}
#
# Predicted class: 1
# Class probabilities: {1: 0.6735339268276271, 2: 0.01142465427499437, 3: 0.07248564110278939, 4: 0.06867716938848091, 5: 0.03646937380727203, 6: 0.03034180279135281, 7: 0.03510048449639485, 8: 0.06557328530494845, 13: 0.006393662006139937}
#
# Predicted class: 7
# Class probabilities: {1: 0.04981802456556659, 2: 0.023212628867620686, 3: 0.06733885615445726, 4: 0.04870317227871498, 5: 0.06260260166033442, 6: 0.17114909824645638, 7: 0.5000012237403346, 8: 0.06511661928040294, 13: 0.012057775206112101}
#
# Predicted class: 4
# Class probabilities: {1: 0.10458993493467701, 2: 0.03488501065913228, 3: 0.13095083770695742, 4: 0.24070716125007405, 5: 0.17948843552726418, 6: 0.12980052542875198, 7: 0.07123707529604006, 8: 0.0856105031331269, 13: 0.02273051606397597}
#
# Predicted class: 8
# Class probabilities: {1: 0.021896682433737644, 2: 0.029076276484730375, 3: 0.0291303010592375, 4: 0.042589564750358085, 5: 0.055907623826942685, 6: 0.031151167764106397, 7: 0.03496962235054503, 8: 0.7058728899679899, 13: 0.04940587136235219}
#
# Predicted class: 1
# Class probabilities: {1: 0.6120669829886576, 2: 0.02802702475805098, 3: 0.06333321855662641, 4: 0.04006420012775481, 5: 0.07808027205415315, 6: 0.05452985844165028, 7: 0.06487961993425737, 8: 0.046143796978728724, 13: 0.012875026160120673}
#
# Predicted class: 6
# Class probabilities: {1: 0.08342083048235471, 2: 0.028439691327530204, 3: 0.06555404377513672, 4: 0.09835102615207679, 5: 0.08309850378656211, 6: 0.4618630355905025, 7: 0.08398631366275708, 8: 0.07611725467608092, 13: 0.01916930054699904}
#
# Predicted class: 6
# Class probabilities: {1: 0.08900649529607946, 2: 0.0844360557100368, 3: 0.12072971594030957, 4: 0.1835895220614343, 5: 0.15518466565075556, 6: 0.22553935951750848, 7: 0.05084431775016314, 8: 0.06303424641360696, 13: 0.02763562166010571}
#
# Predicted class: 5
# Class probabilities: {1: 0.10763024660975092, 2: 0.07670079198970664, 3: 0.07739231041672633, 4: 0.1651967129767481, 5: 0.23653172918991955, 6: 0.14882226536089482, 7: 0.09089561068747881, 8: 0.06457022683827071, 13: 0.0322601059305042}
#
# Predicted class: 5
# Class probabilities: {1: 0.057657997125900425, 2: 0.03793793694886421, 3: 0.13489858348054937, 4: 0.18155948122211954, 5: 0.19172815944291002, 6: 0.1742528799739227, 7: 0.07766198208198608, 8: 0.11017691658568642, 13: 0.034126063138060936}
#
# Predicted class: 8
# Class probabilities: {1: 0.0357133629258228, 2: 0.004714471228569114, 3: 0.014324232479219308, 4: 0.01772074963223471, 5: 0.02444930192036297, 6: 0.034682381063882176, 7: 0.031230197868552644, 8: 0.7905063402015353, 13: 0.046658962679820996}
#
# Predicted class: 8
# Class probabilities: {1: 0.048448920912158376, 2: 0.0033959899749373434, 3: 0.052433942516233255, 4: 0.01549298688382592, 5: 0.011989485001394065, 6: 0.015356178728030913, 7: 0.011521807589580678, 8: 0.8019723709817401, 13: 0.039388317412099215}
#
# Predicted class: 7
# Class probabilities: {1: 0.08175269071183844, 2: 0.06313065442811581, 3: 0.10611700874519449, 4: 0.07553100646323235, 5: 0.06488733032304778, 6: 0.10354357173952874, 7: 0.40805243124664486, 8: 0.08476688061451444, 13: 0.012218425727882872}
#
# Predicted class: 3
# Class probabilities: {1: 0.14207182141042332, 2: 0.1567440552596821, 3: 0.19974756864116303, 4: 0.1341492640289121, 5: 0.11019493114403632, 6: 0.08975166393249757, 7: 0.09469961333229546, 8: 0.06777888539254441, 13: 0.004862196858445333}
#
# Predicted class: 7
# Class probabilities: {1: 0.030961340640326167, 2: 0.03531604997518769, 3: 0.03367558749942226, 4: 0.062358555078541045, 5: 0.031329926448957664, 6: 0.05515429319721081, 7: 0.6157207577098519, 8: 0.10816008522528689, 13: 0.02732340422521579}
#
# Predicted class: 6
# Class probabilities: {1: 0.05469365918159498, 2: 0.024373533686669113, 3: 0.136536772323394, 4: 0.18592753395778347, 5: 0.08939221198510154, 6: 0.3159056975773992, 7: 0.0763978228512847, 8: 0.09788662622900317, 13: 0.01888614220776967}
#
# Predicted class: 8
# Class probabilities: {1: 0.0268845292798025, 2: 0.022545165572491456, 3: 0.02096891050688037, 4: 0.02763140906321603, 5: 0.03552320664005724, 6: 0.024739928076673925, 7: 0.12334109746122308, 8: 0.6813100393390661, 13: 0.037055714060589294}
#
# Predicted class: 4
# Class probabilities: {1: 0.09868674320258518, 2: 0.050265850822580435, 3: 0.19120736762055363, 4: 0.1948740334268497, 5: 0.17936688249592095, 6: 0.1163584594904526, 7: 0.0985738866538958, 8: 0.06563027179962828, 13: 0.005036504487533264}
#
# Predicted class: 4
# Class probabilities: {1: 0.12152691119091845, 2: 0.052794466711257905, 3: 0.12917133626997054, 4: 0.2904971442110714, 5: 0.12279577537693509, 6: 0.10928478689605219, 7: 0.10663033336690675, 8: 0.06270693374208865, 13: 0.004592312234798996}
#
# Predicted class: 6
# Class probabilities: {1: 0.06102759893054016, 2: 0.04185723412814655, 3: 0.06431376153514436, 4: 0.08744160012852896, 5: 0.08845731488338703, 6: 0.462670735084591, 7: 0.09703549946853741, 8: 0.08233797364702221, 13: 0.014858282194102276}
#
# Predicted class: 1
# Class probabilities: {1: 0.6360310850817669, 2: 0.04780320498897025, 3: 0.06768744723641106, 4: 0.05774026579920538, 5: 0.04048341908588385, 6: 0.058391186708225275, 7: 0.029676712432040862, 8: 0.05509629067625627, 13: 0.007090387991240151}
#
# Predicted class: 6
# Class probabilities: {1: 0.06942863185030355, 2: 0.05959725612270387, 3: 0.11045082416646261, 4: 0.10056318186488264, 5: 0.05997627804931062, 6: 0.4595264828869583, 7: 0.07966478213829455, 8: 0.04356211560028941, 13: 0.017230447320794356}
#
# Predicted class: 4
# Class probabilities: {1: 0.08887113147290196, 2: 0.053007861680260504, 3: 0.16146719006009028, 4: 0.2761094237031509, 5: 0.16138638424396487, 6: 0.07173507022639647, 7: 0.10931811620426586, 8: 0.0757312002573086, 13: 0.0023736221516604005}
#
# Predicted class: 13
# Class probabilities: {1: 0.03711327754378691, 2: 0.021365025826584724, 3: 0.011886089227712395, 4: 0.047229558945621364, 5: 0.007240963366635679, 6: 0.0707489361417558, 7: 0.09308539204885195, 8: 0.3361181330748488, 13: 0.37521262382420245}
#
# Predicted class: 8
# Class probabilities: {1: 0.03330369089985041, 2: 0.01498381919999568, 3: 0.026139218914873984, 4: 0.026106842739675135, 5: 0.04263655011890275, 6: 0.039152912107890125, 7: 0.024543695772220632, 8: 0.7212716169676028, 13: 0.07186165327898879}
#
# Predicted class: 8
# Class probabilities: {1: 0.039399484078954564, 2: 0.019698816464373797, 3: 0.05371061629103428, 4: 0.055003231551261356, 5: 0.022609021691156347, 6: 0.052430650707892455, 7: 0.10266433004754529, 8: 0.6047822209186964, 13: 0.04970162824908545}
#
# Predicted class: 4
# Class probabilities: {1: 0.06994551273513423, 2: 0.07283284093487206, 3: 0.17866258549414188, 4: 0.23315043277935987, 5: 0.14639162439044018, 6: 0.09069939597000229, 7: 0.08025670360301827, 8: 0.11456042241020319, 13: 0.013500481682827775}
#
# Predicted class: 4
# Class probabilities: {1: 0.13773509445614315, 2: 0.06708574623319127, 3: 0.10667446968190536, 4: 0.2436245174968762, 5: 0.15271158009621352, 6: 0.12400135405398358, 7: 0.07516236647014957, 8: 0.08396630292682028, 13: 0.00903856858471698}
#
# Predicted class: 13
# Class probabilities: {1: 0.04283711964248558, 2: 0.018340730060668706, 3: 0.05547116506502424, 4: 0.06387572633945461, 5: 0.024931650072036245, 6: 0.03620501613270671, 7: 0.035572336419991475, 8: 0.3595946722811728, 13: 0.36317158398645966}
#
# Predicted class: 4
# Class probabilities: {1: 0.08324958509976965, 2: 0.02658528470431763, 3: 0.1232636161106936, 4: 0.2948629953201525, 5: 0.1088251179250428, 6: 0.1303893471745643, 7: 0.06093807183877518, 8: 0.14048913400115992, 13: 0.03139684782552436}
#
# Predicted class: 4
# Class probabilities: {1: 0.10651727980741095, 2: 0.053151021175334656, 3: 0.20159463820109197, 4: 0.2486115582766262, 5: 0.10919449247286628, 6: 0.10983518582478147, 7: 0.1019342837791793, 8: 0.06406408227310113, 13: 0.005097458189607911}
#
# Predicted class: 7
# Class probabilities: {1: 0.04981802456556659, 2: 0.023212628867620686, 3: 0.06733885615445726, 4: 0.04870317227871498, 5: 0.06260260166033442, 6: 0.17114909824645638, 7: 0.5000012237403346, 8: 0.06511661928040294, 13: 0.012057775206112101}
#
# Predicted class: 6
# Class probabilities: {1: 0.08064170809413786, 2: 0.028061336878562007, 3: 0.05915540342724925, 4: 0.07480898024648004, 5: 0.06944019271368515, 6: 0.559030012359143, 7: 0.06786892982400922, 8: 0.05253414095947926, 13: 0.008459295497254491}
#
# Predicted class: 7
# Class probabilities: {1: 0.03869841026483858, 2: 0.021881099230047725, 3: 0.05469332323986287, 4: 0.09207657183695858, 5: 0.0608555159836336, 6: 0.06455715345152473, 7: 0.5872513494193058, 8: 0.07190654867447444, 13: 0.008080027899353812}
#
# Predicted class: 1
# Class probabilities: {1: 0.6852656568009738, 2: 0.018869157670492322, 3: 0.0749717509016205, 4: 0.04177236443512823, 5: 0.02864482262121245, 6: 0.03502552579121638, 7: 0.08008523616293624, 8: 0.03242118886714355, 13: 0.002944296749276209}
#
# Predicted class: 7
# Class probabilities: {1: 0.05768657596191485, 2: 0.049843048332710735, 3: 0.061153646863547156, 4: 0.06174877725951054, 5: 0.05524665655329375, 6: 0.14464063222962242, 7: 0.4107828220196785, 8: 0.14512494683118712, 13: 0.013772893948534948}
#
# Predicted class: 8
# Class probabilities: {1: 0.021896682433737644, 2: 0.029076276484730375, 3: 0.0291303010592375, 4: 0.042589564750358085, 5: 0.055907623826942685, 6: 0.031151167764106397, 7: 0.03496962235054503, 8: 0.7058728899679899, 13: 0.04940587136235219}
#
# Predicted class: 8
# Class probabilities: {1: 0.05101351078708865, 2: 0.004194993255143631, 3: 0.046903106638277986, 4: 0.007983178671035327, 5: 0.015421847153003076, 6: 0.024783987579372887, 7: 0.0279402071248783, 8: 0.7773369446510645, 13: 0.04442222414013553}
#
# Predicted class: 3
# Class probabilities: {1: 0.08104528495991146, 2: 0.1322330423148173, 3: 0.2867776574727974, 4: 0.12692403336820154, 5: 0.06527714204364539, 6: 0.16418271687152716, 7: 0.05159814249444792, 8: 0.06720268158115078, 13: 0.024759298893501182}
#
# Predicted class: 4
# Class probabilities: {1: 0.09925914907853603, 2: 0.052119955009610204, 3: 0.15988761829179637, 4: 0.29068846528926556, 5: 0.1299377689085158, 6: 0.1062589912668178, 7: 0.06034062427874213, 8: 0.05212764237223258, 13: 0.04937978550448327}
#
# Predicted class: 4
# Class probabilities: {1: 0.14799162975705515, 2: 0.13619968987314646, 3: 0.0901285606811233, 4: 0.22545421329008836, 5: 0.12188017211625064, 6: 0.1062257768984966, 7: 0.07881040660330066, 8: 0.07834248078665411, 13: 0.014967069993884672}
#
# Predicted class: 8
# Class probabilities: {1: 0.05032327596192251, 2: 0.011832850587588782, 3: 0.01500308746729729, 4: 0.01979789232146169, 5: 0.043257171273520696, 6: 0.013499161156472308, 7: 0.017472125038393682, 8: 0.7732556335154427, 13: 0.05555880267790055}
#
# Predicted class: 3
# Class probabilities: {1: 0.1292186456779771, 2: 0.1266252668170817, 3: 0.21581266752241585, 4: 0.1478140830772335, 5: 0.08827058806085122, 6: 0.09399839303328592, 7: 0.0826123674162012, 8: 0.08529778472829072, 13: 0.030350203666662714}
#
# Predicted class: 8
# Class probabilities: {1: 0.03232645521826454, 2: 0.005061541509159119, 3: 0.040941894196079846, 4: 0.03377124529868551, 5: 0.014062602920363806, 6: 0.030092149450234938, 7: 0.10422424609481408, 8: 0.696608000611272, 13: 0.0429118647011263}
#
# Predicted class: 3
# Class probabilities: {1: 0.07580313399678394, 2: 0.05476139017639713, 3: 0.3759389359397578, 4: 0.1419564816541523, 5: 0.05562159552904252, 6: 0.10726500529348323, 7: 0.06253612166967706, 8: 0.10123718093671874, 13: 0.0248801548039873}
#
# Predicted class: 7
# Class probabilities: {1: 0.04287103545152006, 2: 0.012244968444361617, 3: 0.06631259063755437, 4: 0.06157958323685803, 5: 0.06130905911170086, 6: 0.11854011563960812, 7: 0.5662140364234902, 8: 0.06560893345708657, 13: 0.005319677597819981}
#
# Predicted class: 4
# Class probabilities: {1: 0.09091540173554839, 2: 0.04990528030152093, 3: 0.13362184379114422, 4: 0.2628871226966519, 5: 0.17952287252309818, 6: 0.10222461323476258, 7: 0.09939890115180247, 8: 0.06642013866669252, 13: 0.01510382589877865}
#
# Predicted class: 13
# Class probabilities: {1: 0.0579093574987437, 2: 0.02344900319546516, 3: 0.05915828746606018, 4: 0.0709415667708513, 5: 0.03303520413871371, 6: 0.04814027836976468, 7: 0.07955414699618758, 8: 0.24883364421428503, 13: 0.37897851134992866}
#
# Predicted class: 8
# Class probabilities: {1: 0.05219703553248808, 2: 0.020491971539273075, 3: 0.05432524552337505, 4: 0.035694250473520484, 5: 0.040177867257965946, 6: 0.09541924154165239, 7: 0.07216692459714125, 8: 0.3535959913951353, 13: 0.2759314721394483}
#
# Predicted class: 5
# Class probabilities: {1: 0.09297384851709113, 2: 0.044756301480964156, 3: 0.11791422581913574, 4: 0.20246126905910916, 5: 0.23810167600342258, 6: 0.11774732656061845, 7: 0.05469696277872818, 8: 0.09386346346350345, 13: 0.037484926317426955}
#
# Predicted class: 1
# Class probabilities: {1: 0.5801662823124862, 2: 0.03898598336248072, 3: 0.06154625110213358, 4: 0.07833964780273898, 5: 0.042702805588049945, 6: 0.07328612192225478, 7: 0.04316982522446453, 8: 0.056369448606996816, 13: 0.025433634078394367}
#
# Predicted class: 8
# Class probabilities: {1: 0.02026266281970118, 2: 0.0022652825369703757, 3: 0.0131048090692129, 4: 0.016649042218163854, 5: 0.055794415038673655, 6: 0.017039252371537944, 7: 0.038463117129542694, 8: 0.80034419594228, 13: 0.03607722287391729}
#
# Predicted class: 1
# Class probabilities: {1: 0.7105414857636758, 2: 0.019883048292325435, 3: 0.06208553425234356, 4: 0.06318751284916051, 5: 0.020988177984048315, 6: 0.037242185731437144, 7: 0.054118531072052584, 8: 0.030542768132337063, 13: 0.001410755922619292}
#
# Predicted class: 8
# Class probabilities: {1: 0.04483383040245448, 2: 0.008945273974533218, 3: 0.02222934918800678, 4: 0.014828606146803994, 5: 0.029167367458703738, 6: 0.038477202393014824, 7: 0.08810335909315459, 8: 0.6820817164212087, 13: 0.07133329492211977}
#
# Predicted class: 4
# Class probabilities: {1: 0.12846322339077904, 2: 0.05086699408269905, 3: 0.20263629170488448, 4: 0.21888305417017828, 5: 0.13488715145854246, 6: 0.09227682500786541, 7: 0.0846048927408352, 8: 0.07398545084571621, 13: 0.013396116598499801}
#
# Predicted class: 6
# Class probabilities: {1: 0.08909797581868746, 2: 0.03557482759752668, 3: 0.06013756886496643, 4: 0.10848419267902866, 5: 0.07347399953808563, 6: 0.453007283482037, 7: 0.07648123942736337, 8: 0.08059413953613763, 13: 0.023148773056167138}
#
# Predicted class: 3
# Class probabilities: {1: 0.15220643805404246, 2: 0.09579564922943669, 3: 0.24384685060264044, 4: 0.1792771925726529, 5: 0.08370422941881055, 6: 0.07068267032102583, 7: 0.09316841328199335, 8: 0.06365926868180656, 13: 0.017659287837591166}
#
# Predicted class: 7
# Class probabilities: {1: 0.030961340640326167, 2: 0.03531604997518769, 3: 0.03367558749942226, 4: 0.062358555078541045, 5: 0.031329926448957664, 6: 0.05515429319721081, 7: 0.6157207577098519, 8: 0.10816008522528689, 13: 0.02732340422521579}
#
# Predicted class: 13
# Class probabilities: {1: 0.07712768608416572, 2: 0.027303600878565096, 3: 0.02176624547033007, 4: 0.10568626617256252, 5: 0.008716188559911003, 6: 0.061436688491711244, 7: 0.06842599901139862, 8: 0.2371322195498553, 13: 0.39240510578150023}
#
# Predicted class: 1
# Class probabilities: {1: 0.5448031484175629, 2: 0.04183086881898468, 3: 0.15747637187749186, 4: 0.042900818165723026, 5: 0.023099161873978303, 6: 0.04245725575710921, 7: 0.043564717349688704, 8: 0.10070627192146042, 13: 0.0031613858180007753}
#
# Predicted class: 8
# Class probabilities: {1: 0.03549247724578726, 2: 0.006143504886614654, 3: 0.016274294015869488, 4: 0.015777793620067204, 5: 0.05422647025277331, 6: 0.025453292087289324, 7: 0.022215219985987026, 8: 0.7570260035603319, 13: 0.06739094434528009}
#
# Predicted class: 1
# Class probabilities: {1: 0.5581323028768311, 2: 0.023905411614526917, 3: 0.0789724218682546, 4: 0.06698666633335755, 5: 0.05237265493651257, 6: 0.07196844469939055, 7: 0.056774972233809444, 8: 0.0695264573078654, 13: 0.021360668129451893}
#
# Predicted class: 3
# Class probabilities: {1: 0.12644606907385006, 2: 0.12331199432618765, 3: 0.20348474365043048, 4: 0.1497241119395624, 5: 0.09559463099883274, 6: 0.11449350371387797, 7: 0.05828994501307519, 8: 0.10407107420129248, 13: 0.024583927082890866}
#
# Predicted class: 3
# Class probabilities: {1: 0.11625907479863493, 2: 0.1094547152879942, 3: 0.20092689600673974, 4: 0.1559329171856648, 5: 0.1135505811438724, 6: 0.12768068332203356, 7: 0.0735275563084572, 8: 0.07915431539295185, 13: 0.023513260553651275}
#
# Predicted class: 7
# Class probabilities: {1: 0.030961340640326167, 2: 0.03531604997518769, 3: 0.03367558749942226, 4: 0.062358555078541045, 5: 0.031329926448957664, 6: 0.05515429319721081, 7: 0.6157207577098519, 8: 0.10816008522528689, 13: 0.02732340422521579}
#
# Predicted class: 13
# Class probabilities: {1: 0.0681941970043196, 2: 0.026907560404046467, 3: 0.049712399612333036, 4: 0.06125741808720017, 5: 0.040682000219273325, 6: 0.056959240546075, 7: 0.09635838016569419, 8: 0.24591976111232466, 13: 0.35400904284873347}
#
# Predicted class: 8
# Class probabilities: {1: 0.03308440570032659, 2: 0.015283059831482348, 3: 0.062292078323233024, 4: 0.03784539122432293, 5: 0.06127492038336231, 6: 0.06425315541966346, 7: 0.05151176341513901, 8: 0.5623215574957839, 13: 0.11213366820668655}
#
# Predicted class: 3
# Class probabilities: {1: 0.11306094740180692, 2: 0.14292283089588706, 3: 0.1933723454094134, 4: 0.14087461081386796, 5: 0.1748767855066748, 6: 0.04889154862015616, 7: 0.08678702028756738, 8: 0.09041976417998328, 13: 0.008794146884642912}
#
# Predicted class: 3
# Class probabilities: {1: 0.06629716644421703, 2: 0.12173286128691548, 3: 0.329850968098525, 4: 0.12664948918293878, 5: 0.07028566204440169, 6: 0.09011277177986303, 7: 0.07744990559673244, 8: 0.0914349602439197, 13: 0.02618621532248692}
#
# Predicted class: 6
# Class probabilities: {1: 0.10790306953990067, 2: 0.029724023814415076, 3: 0.04781312399703433, 4: 0.11048856747059997, 5: 0.05223278981651868, 6: 0.48894482151236135, 7: 0.08252805879784594, 8: 0.06246625672993577, 13: 0.017899288321388027}
#
# Predicted class: 7
# Class probabilities: {1: 0.033071692561837375, 2: 0.013435108044167395, 3: 0.04345911846464532, 4: 0.027806788724986542, 5: 0.05091953669314391, 6: 0.06148945146123238, 7: 0.7249395594668432, 8: 0.03914825192502737, 13: 0.005730492658116357}
#
# Predicted class: 1
# Class probabilities: {1: 0.5930990583310041, 2: 0.032228502171109286, 3: 0.06851329495784533, 4: 0.047253306031860835, 5: 0.05641030158917693, 6: 0.06758049877418076, 7: 0.05474050010107372, 8: 0.0757129469490343, 13: 0.0044615910947145366}
#
# Predicted class: 3
# Class probabilities: {1: 0.09547549586797272, 2: 0.07804677408030726, 3: 0.2798402424225548, 4: 0.17951477490165052, 5: 0.10717178243109367, 6: 0.08227274461256433, 7: 0.09818560426553949, 8: 0.06260654671081428, 13: 0.0168860347075029}
#
# Predicted class: 8
# Class probabilities: {1: 0.029812953544524224, 2: 0.014056861289224584, 3: 0.031062038578847342, 4: 0.02607885924744453, 5: 0.031169121073069083, 6: 0.020682883473246177, 7: 0.15648124699550647, 8: 0.6663694091783258, 13: 0.024286626619811735}
#
# Predicted class: 3
# Class probabilities: {1: 0.07498072922721656, 2: 0.11899695639465828, 3: 0.2523709547357476, 4: 0.14309755173139335, 5: 0.1114872991270294, 6: 0.1500464736676871, 7: 0.047926332443048114, 8: 0.07866736357231112, 13: 0.022426339100908375}
#
# Predicted class: 8
# Class probabilities: {1: 0.04888777678778729, 2: 0.003562399792226549, 3: 0.05694027414246679, 4: 0.016776923360654363, 5: 0.01400619218985701, 6: 0.030429006675255145, 7: 0.012784890937277178, 8: 0.7767641350437197, 13: 0.0398484010707558}
#
# Predicted class: 6
# Class probabilities: {1: 0.06425974383366967, 2: 0.0398136883194421, 3: 0.11974183420412231, 4: 0.061100246477215084, 5: 0.05834319984974645, 6: 0.47758199369150023, 7: 0.09292570138631151, 8: 0.07348471782006984, 13: 0.012748874417922555}
#
# Predicted class: 1
# Class probabilities: {1: 0.7352062511212197, 2: 0.02517078332138895, 3: 0.02376246354605126, 4: 0.041821156379798885, 5: 0.03207015658685773, 6: 0.03013304296677709, 7: 0.022099032933518267, 8: 0.07723198328392612, 13: 0.012505129860461732}
#
# Predicted class: 4
# Class probabilities: {1: 0.0948868201785932, 2: 0.08608388175000904, 3: 0.16686038684541118, 4: 0.27904052139546104, 5: 0.12426547981203895, 6: 0.13377773408337687, 7: 0.053905284550517574, 8: 0.04504386367466703, 13: 0.016136027709925192}
#
# Predicted class: 7
# Class probabilities: {1: 0.026138862968931625, 2: 0.04819228533050724, 3: 0.06690176350346663, 4: 0.07885028314268326, 5: 0.03662787478742381, 6: 0.05300482449515781, 7: 0.5392665715374567, 8: 0.10327896963017681, 13: 0.047738564604196225}
#
# Predicted class: 3
# Class probabilities: {1: 0.14773845241972386, 2: 0.07974769593167845, 3: 0.2920319880858496, 4: 0.16275215229711892, 5: 0.08066412141136688, 6: 0.0702471153221336, 7: 0.08116590402135053, 8: 0.07090307938089822, 13: 0.014749491129879853}
#
# Predicted class: 4
# Class probabilities: {1: 0.10243417533844762, 2: 0.06470210176953867, 3: 0.15254507369945497, 4: 0.2951871276310625, 5: 0.13135558152822094, 6: 0.10530987097001879, 7: 0.08120828107080019, 8: 0.057520505772411606, 13: 0.009737282220044835}
#
# Predicted class: 6
# Class probabilities: {1: 0.06370318386427114, 2: 0.024974343039550793, 3: 0.07100619119145012, 4: 0.11193874740460481, 5: 0.08878367228980742, 6: 0.4496446651997301, 7: 0.05745325667527974, 8: 0.09809527449437827, 13: 0.03440066584092754}
#
# Predicted class: 3
# Class probabilities: {1: 0.11168422528190768, 2: 0.05620903782575706, 3: 0.192242899422787, 4: 0.14536863832585695, 5: 0.1783036952798268, 6: 0.1700022248863267, 7: 0.05306863312573066, 8: 0.07802430255678965, 13: 0.015096343295017576}
#
# Predicted class: 4
# Class probabilities: {1: 0.08252725108393158, 2: 0.046028978994722435, 3: 0.14457880620207536, 4: 0.3251707857609509, 5: 0.13130850532828253, 6: 0.14262949853704118, 7: 0.07213828265381309, 8: 0.04215591849112727, 13: 0.013461972948055725}
#
# Predicted class: 1
# Class probabilities: {1: 0.6120669829886576, 2: 0.02802702475805098, 3: 0.06333321855662641, 4: 0.04006420012775481, 5: 0.07808027205415315, 6: 0.05452985844165028, 7: 0.06487961993425737, 8: 0.046143796978728724, 13: 0.012875026160120673}
#
# Predicted class: 13
# Class probabilities: {1: 0.09195070816015204, 2: 0.007502197458724077, 3: 0.0337317945848716, 4: 0.0665442651954948, 5: 0.036630213051225526, 6: 0.03928255110881612, 7: 0.06023381043330695, 8: 0.2918434163787973, 13: 0.37228104362861153}
#
# Predicted class: 8
# Class probabilities: {1: 0.06515591872992132, 2: 0.01053864982807063, 3: 0.03555817201324558, 4: 0.0419187427012684, 5: 0.028665276363035976, 6: 0.04714016021633819, 7: 0.03280574255539209, 8: 0.6687674818767447, 13: 0.06944985571598286}
#
# Predicted class: 7
# Class probabilities: {1: 0.03400707871481771, 2: 0.030003235755746024, 3: 0.07015663503564108, 4: 0.06376395898669762, 5: 0.02429910622965157, 6: 0.0472952264022377, 7: 0.6264062863336712, 8: 0.09575196215936504, 13: 0.008316510382172198}
#
# Predicted class: 8
# Class probabilities: {1: 0.03853110387102438, 2: 0.023310946340559458, 3: 0.012893144941603369, 4: 0.04079003687781499, 5: 0.0028686741836348372, 6: 0.03072218124807111, 7: 0.07612479220855689, 8: 0.6891231997987028, 13: 0.08563592053003195}
#
# Predicted class: 7
# Class probabilities: {1: 0.035305197729444925, 2: 0.02168830277563773, 3: 0.07534006925467715, 4: 0.050437444485018565, 5: 0.020669792211306357, 6: 0.07754968272819794, 7: 0.5516316199992575, 8: 0.13329533362622198, 13: 0.03408255719023789}
#
# Predicted class: 5
# Class probabilities: {1: 0.06793759359426514, 2: 0.05698300446489631, 3: 0.12130506204201087, 4: 0.20011641162567226, 5: 0.20635059294534874, 6: 0.18607219492297714, 7: 0.04703398658124331, 8: 0.09324793266921529, 13: 0.02095322115437068}
#
# Predicted class: 6
# Class probabilities: {1: 0.04398651226088216, 2: 0.0458890568041103, 3: 0.11488502415280435, 4: 0.1684502407946741, 5: 0.10657990551329014, 6: 0.3650098979560266, 7: 0.0640108776197551, 8: 0.0662750050631619, 13: 0.02491347983529547}
#
# ...
#
# Predicted class: 13
# Class probabilities: {1: 0.05555882495269012, 2: 0.024740356737573334, 3: 0.02406538641627828, 4: 0.07270920027682234, 5: 0.016162745231784466, 6: 0.05981487556019089, 7: 0.06345779946953031, 8: 0.2854098217755779, 13: 0.3980809895795523}
#
# Predicted class: 4
# Class probabilities: {1: 0.0722616936044942, 2: 0.11527844350655396, 3: 0.1591711386630242, 4: 0.2597612666472626, 5: 0.12667651193145182, 6: 0.048496326636802055, 7: 0.06687848367477348, 8: 0.1390883556544858, 13: 0.012387779681151545}
#
# Predicted class: 5
# Class probabilities: {1: 0.1280624962745024, 2: 0.06260837791079174, 3: 0.1765106772811967, 4: 0.17658001074037205, 5: 0.18278966006650627, 6: 0.09909100314704569, 7: 0.08259733151516771, 8: 0.07738899538023801, 13: 0.014371447684179271}
#
# Predicted class: 3
# Class probabilities: {1: 0.1585749231012194, 2: 0.08500117241399818, 3: 0.3196421142530538, 4: 0.1429431942002443, 5: 0.07531126439862898, 6: 0.058130372148461895, 7: 0.06267999187402946, 8: 0.07925042583259982, 13: 0.018466541777764203}
#
# Predicted class: 1
# Class probabilities: {1: 0.7952107653749969, 2: 0.011674778564028425, 3: 0.05010263682195678, 4: 0.02314249453051126, 5: 0.02794722160541296, 6: 0.019661495386624896, 7: 0.016269502981209785, 8: 0.0524239076444043, 13: 0.0035671970908543}
#
# Predicted class: 4
# Class probabilities: {1: 0.08308515993052369, 2: 0.08737092914221173, 3: 0.1432066926938752, 4: 0.2720481550859653, 5: 0.0663030260311602, 6: 0.09406002043487972, 7: 0.0980446695150629, 8: 0.13834076622551622, 13: 0.017540580940805003}
#
# Predicted class: 1
# Class probabilities: {1: 0.46712211971127593, 2: 0.04636970095991692, 3: 0.10615775336360012, 4: 0.06525239714293668, 5: 0.05651960688838964, 6: 0.07036651643399408, 7: 0.09764852549794184, 8: 0.08321427519152325, 13: 0.007349104810421533}
#
# Predicted class: 5
# Class probabilities: {1: 0.1015567316642337, 2: 0.052287678525886915, 3: 0.11473578762136112, 4: 0.19232798051347264, 5: 0.21844110426789462, 6: 0.13304370992190656, 7: 0.06812422370922551, 8: 0.0911234088015029, 13: 0.028359374974515975}
#
# Predicted class: 8
# Class probabilities: {1: 0.09739245569154646, 2: 0.00813151067047294, 3: 0.03576556724847979, 4: 0.050482515602106946, 5: 0.036039789498658, 6: 0.05504476587188915, 7: 0.12534370562866162, 8: 0.3232498042028048, 13: 0.2685498855853802}
#
# Predicted class: 1
# Class probabilities: {1: 0.17625768960452365, 2: 0.1345429943005502, 3: 0.1700349615983324, 4: 0.152042401865706, 5: 0.08600349398928692, 6: 0.0963723533397516, 7: 0.08047386015089777, 8: 0.07069120173024528, 13: 0.033581043420706155}
#
# Predicted class: 1
# Class probabilities: {1: 0.5291936693105411, 2: 0.029940569655358542, 3: 0.10842167602833631, 4: 0.05306954947212312, 5: 0.026245400154166394, 6: 0.05892628111898598, 7: 0.0837561398851921, 8: 0.08529776513543601, 13: 0.025148949239860524}
#
# Predicted class: 7
# Class probabilities: {1: 0.024892437801234027, 2: 0.03677462754522973, 3: 0.04220113505337576, 4: 0.05363264409576383, 5: 0.0472371302468659, 6: 0.04305322910434751, 7: 0.6773089839016947, 8: 0.05985105844648951, 13: 0.015048753804998911}
#
# Predicted class: 8
# Class probabilities: {1: 0.06499584282919842, 2: 0.008756136187017902, 3: 0.03457398133080733, 4: 0.025830144435376623, 5: 0.016988199032310507, 6: 0.057897406785075566, 7: 0.034673505933569986, 8: 0.718082471634651, 13: 0.038202311831992776}
#
# Predicted class: 3
# Class probabilities: {1: 0.10772868050299139, 2: 0.11840120233887634, 3: 0.3264928638837967, 4: 0.12331068747483734, 5: 0.052139106333035964, 6: 0.11326791520393509, 7: 0.06837647802294235, 8: 0.07534245751689306, 13: 0.014940608722691635}
#
# Predicted class: 7
# Class probabilities: {1: 0.054580397125062206, 2: 0.00797175375924328, 3: 0.03880294158205854, 4: 0.09237051966842379, 5: 0.059738187956991165, 6: 0.13086747532230064, 7: 0.5243205097317565, 8: 0.07442511196243849, 13: 0.01692310289172555}
#
# Predicted class: 7
# Class probabilities: {1: 0.045412958985213615, 2: 0.008280686782572436, 3: 0.04340850441037917, 4: 0.056998174737936405, 5: 0.01775494640523327, 6: 0.057125512331250024, 7: 0.6518916970137246, 8: 0.10875253481073743, 13: 0.010374984522953108}
#
# Predicted class: 13
# Class probabilities: {1: 0.10119541890013424, 2: 0.017458557751208238, 3: 0.03176022877256213, 4: 0.06103767062482913, 5: 0.022843491005244226, 6: 0.042166024337944745, 7: 0.1264782937564312, 8: 0.2796513656884706, 13: 0.3174089491631755}
#
# Predicted class: 1
# Class probabilities: {1: 0.6063485623296188, 2: 0.03253379980821296, 3: 0.1383218019673335, 4: 0.025203403608067037, 5: 0.044983147779322254, 6: 0.04174316342104172, 7: 0.06701639621924951, 8: 0.03719425145948932, 13: 0.006655473407664792}
#
# Predicted class: 1
# Class probabilities: {1: 0.5601232540880187, 2: 0.023797454397155988, 3: 0.06449372114197767, 4: 0.0485300796694682, 5: 0.08076678818826497, 6: 0.09294421215587498, 7: 0.054238968922152075, 8: 0.0537997540555123, 13: 0.02130576738157508}
#
# Predicted class: 4
# Class probabilities: {1: 0.08415223894557333, 2: 0.06809077103208899, 3: 0.12165520906545466, 4: 0.20436794742042624, 5: 0.20237394699918418, 6: 0.12889286920969537, 7: 0.06708257589052542, 8: 0.10264431048971992, 13: 0.020740130947331844}
#
# Predicted class: 6
# Class probabilities: {1: 0.09292336986777341, 2: 0.0333440892288205, 3: 0.05142665179620785, 4: 0.10801289872144255, 5: 0.08212608719225524, 6: 0.47675787481740556, 7: 0.0972398493171686, 8: 0.0483206600700729, 13: 0.009848518988853305}
#
# Predicted class: 7
# Class probabilities: {1: 0.030728694055818368, 2: 0.014942457489764645, 3: 0.05216461058187553, 4: 0.03996876840516759, 5: 0.02561582823218554, 6: 0.06423298630163059, 7: 0.7132591858556031, 8: 0.05486294918549468, 13: 0.004224519892459739}
#
# Predicted class: 8
# Class probabilities: {1: 0.050252100221893574, 2: 0.010223122391028185, 3: 0.07083685285862504, 4: 0.036716087207551026, 5: 0.03125919505719393, 6: 0.05784028833089002, 7: 0.04288907131656245, 8: 0.6406383129866567, 13: 0.05934496962959894}
#
# Predicted class: 7
# Class probabilities: {1: 0.028003326799283326, 2: 0.015796151353733398, 3: 0.022820125525623944, 4: 0.05340047685899526, 5: 0.02591206003928335, 6: 0.05560004569152693, 7: 0.6868350336583998, 8: 0.09884068986606107, 13: 0.012792090207092583}
#
# Predicted class: 7
# Class probabilities: {1: 0.019884478194158103, 2: 0.018135636844536136, 3: 0.0120459218719434, 4: 0.03899037055178351, 5: 0.01249686947463865, 6: 0.03942353606830123, 7: 0.7675524113330017, 8: 0.07787596980653758, 13: 0.013594805855099706}
#
# Predicted class: 6
# Class probabilities: {1: 0.1086042138115443, 2: 0.021939254819524655, 3: 0.0799066183852577, 4: 0.11558967643454225, 5: 0.06425440495299133, 6: 0.4642778811201477, 7: 0.06457728957972882, 8: 0.07200613866996108, 13: 0.00884452222630221}
#
# Predicted class: 8
# Class probabilities: {1: 0.05093495959110849, 2: 0.006752930578260491, 3: 0.013912019354042333, 4: 0.011251333014102596, 5: 0.03592995972630867, 6: 0.03878930892602246, 7: 0.0911840197605371, 8: 0.672481750702864, 13: 0.07876371834675396}
#
# Predicted class: 7
# Class probabilities: {1: 0.019269721417779256, 2: 0.010698706786679951, 3: 0.02008142354745172, 4: 0.01815628028877502, 5: 0.0324378151915428, 6: 0.025308926816348217, 7: 0.7965239697572765, 8: 0.06954321418145425, 13: 0.007979942012692117}
#
# Predicted class: 1
# Class probabilities: {1: 0.5479577876878915, 2: 0.02771083603477201, 3: 0.09755473152093966, 4: 0.05821939347568319, 5: 0.03983153101225435, 6: 0.05346441565973903, 7: 0.04117938296521439, 8: 0.10068312280656566, 13: 0.033398798836940226}
#
# Predicted class: 8
# Class probabilities: {1: 0.0242057831596942, 2: 0.02036027878867596, 3: 0.034758691523199034, 4: 0.03691062052338779, 5: 0.0676719896691737, 6: 0.031662259501989566, 7: 0.043891424364310684, 8: 0.6950569016083896, 13: 0.04548205086117925}
#
# Predicted class: 13
# Class probabilities: {1: 0.08118114148386227, 2: 0.01362494958833472, 3: 0.04123366866104546, 4: 0.06267304947380375, 5: 0.015802311402913726, 6: 0.05170061980870841, 7: 0.09166111488000843, 8: 0.3096816705638056, 13: 0.3324414741375178}
#
# Predicted class: 3
# Class probabilities: {1: 0.15423692218254614, 2: 0.08319397178929, 3: 0.27308207917642474, 4: 0.14708197035580517, 5: 0.1352327761910253, 6: 0.06630115510741147, 7: 0.055618797730192265, 8: 0.08054745633592081, 13: 0.004704871131384018}
#
# Predicted class: 1
# Class probabilities: {1: 0.7075969015431558, 2: 0.016559544278108025, 3: 0.08122619262929127, 4: 0.031797887645224995, 5: 0.04560556253214528, 6: 0.050743643344604, 7: 0.010001381020687596, 8: 0.05217329558635931, 13: 0.00429559142042367}
#
# Predicted class: 1
# Class probabilities: {1: 0.7176592703464285, 2: 0.010816883928024398, 3: 0.05979283177854172, 4: 0.03332158069923919, 5: 0.03761101297988479, 6: 0.035761789581002, 7: 0.04952590671950815, 8: 0.05427428344521612, 13: 0.001236440522154808}
#
# Predicted class: 8
# Class probabilities: {1: 0.045909158540782834, 2: 0.006045952735521669, 3: 0.014885798369996461, 4: 0.018678397976538447, 5: 0.020671065460138013, 6: 0.012929981544208796, 7: 0.027626505648186226, 8: 0.8069168150802786, 13: 0.04633632464434912}
#
# Predicted class: 3
# Class probabilities: {1: 0.10543563165437629, 2: 0.06309869693709291, 3: 0.3188729275064368, 4: 0.13708205947474217, 5: 0.13412561659466787, 6: 0.11695594106958751, 7: 0.06506601479348635, 8: 0.05235448381681754, 13: 0.007008628152792605}
#
# Predicted class: 3
# Class probabilities: {1: 0.0806419351493039, 2: 0.07349395472585082, 3: 0.294198355248377, 4: 0.11946589905959877, 5: 0.14288473043687008, 6: 0.114412203359539, 7: 0.07738612726418263, 8: 0.060109057383115894, 13: 0.037407737373161894}
#
# Predicted class: 8
# Class probabilities: {1: 0.05233644609773425, 2: 0.008247497868607486, 3: 0.02863846383428793, 4: 0.014029461427204867, 5: 0.018004638435010618, 6: 0.04466601832930735, 7: 0.00946311584443844, 8: 0.7700441646346232, 13: 0.054570193528785504}
#
# Predicted class: 6
# Class probabilities: {1: 0.06342141927956975, 2: 0.01830583795367909, 3: 0.07498411762716552, 4: 0.11461695214713886, 5: 0.11897412042849154, 6: 0.43923163773252677, 7: 0.08430951640767333, 8: 0.07141293829124443, 13: 0.01474346013251073}
#
# Predicted class: 8
# Class probabilities: {1: 0.04080904190292255, 2: 0.02373559385572086, 3: 0.03249383417402053, 4: 0.045047417979941794, 5: 0.0208692194040095, 6: 0.03839422662690636, 7: 0.037531819297831844, 8: 0.3984011726915928, 13: 0.3627176740670538}
#
# Predicted class: 4
# Class probabilities: {1: 0.10587368147106625, 2: 0.057342059009453966, 3: 0.14594894876864958, 4: 0.2685738584749706, 5: 0.11430148069161968, 6: 0.11753585943633894, 7: 0.08529458808646753, 8: 0.07046646566794042, 13: 0.034663058393493}
#
# Predicted class: 4
# Class probabilities: {1: 0.09925914907853603, 2: 0.052119955009610204, 3: 0.15988761829179637, 4: 0.29068846528926556, 5: 0.1299377689085158, 6: 0.1062589912668178, 7: 0.06034062427874213, 8: 0.05212764237223258, 13: 0.04937978550448327}
#
# Predicted class: 4
# Class probabilities: {1: 0.05918713395137772, 2: 0.09552141111098106, 3: 0.16318705447699475, 4: 0.26050031110095795, 5: 0.12053976828463733, 6: 0.10966301145168504, 7: 0.07735607334219888, 8: 0.09163779708239655, 13: 0.02240743919877067}
#
# Predicted class: 6
# Class probabilities: {1: 0.10790306953990067, 2: 0.029724023814415076, 3: 0.04781312399703433, 4: 0.11048856747059997, 5: 0.05223278981651868, 6: 0.48894482151236135, 7: 0.08252805879784594, 8: 0.06246625672993577, 13: 0.017899288321388027}
#
# Predicted class: 13
# Class probabilities: {1: 0.07798254390658377, 2: 0.0165165392107608, 3: 0.04067433079467022, 4: 0.03407758463504337, 5: 0.05613412371367396, 6: 0.03465914060313062, 7: 0.08031723876867855, 8: 0.32088863056803385, 13: 0.3387498677994249}
#
# Predicted class: 1
# Class probabilities: {1: 0.5193704861931921, 2: 0.03569237861804408, 3: 0.11023337128423827, 4: 0.04751921195609462, 5: 0.034676875098337646, 6: 0.09423011829075169, 7: 0.06753112940870645, 8: 0.08130404849115523, 13: 0.009442380659479823}
#
# Predicted class: 3
# Class probabilities: {1: 0.0551666545969268, 2: 0.10357272701890655, 3: 0.32137262051971477, 4: 0.13765312677213398, 5: 0.08110800146198667, 6: 0.15191232648460995, 7: 0.04671978178317218, 8: 0.07933440432178301, 13: 0.023160357040766154}
#
# Predicted class: 6
# Class probabilities: {1: 0.07649274757927545, 2: 0.043110388062512495, 3: 0.10099434556613512, 4: 0.08616976952182231, 5: 0.05177480055631166, 6: 0.4509502707928875, 7: 0.108769068029445, 8: 0.07051714306818715, 13: 0.011221466823423532}
#
# Predicted class: 1
# Class probabilities: {1: 0.7175399987042205, 2: 0.015038023807747424, 3: 0.08975089281581217, 4: 0.028534333348306306, 5: 0.052872274339905136, 6: 0.03718735895442001, 7: 0.01241110501007918, 8: 0.040430865322836226, 13: 0.006235147696673049}
#
# Predicted class: 3
# Class probabilities: {1: 0.11625907479863493, 2: 0.1094547152879942, 3: 0.20092689600673974, 4: 0.1559329171856648, 5: 0.1135505811438724, 6: 0.12768068332203356, 7: 0.0735275563084572, 8: 0.07915431539295185, 13: 0.023513260553651275}
#
# Predicted class: 8
# Class probabilities: {1: 0.050124319913714126, 2: 0.01803443091082841, 3: 0.04767954154232657, 4: 0.06277192480204184, 5: 0.026984584365262538, 6: 0.03475160292707992, 7: 0.05862096536388471, 8: 0.3521512987469769, 13: 0.348881331427885}
#
# Predicted class: 4
# Class probabilities: {1: 0.0995370714798866, 2: 0.07146219547034621, 3: 0.0971133068028429, 4: 0.24383009730158695, 5: 0.11637653364258882, 6: 0.20258322489775565, 7: 0.06249450336712374, 8: 0.08706207429419846, 13: 0.019540992743670677}
#
# Predicted class: 7
# Class probabilities: {1: 0.06180478946043543, 2: 0.05228797080210504, 3: 0.09012009234409459, 4: 0.042426790499567296, 5: 0.044806205254959215, 6: 0.2110881800079581, 7: 0.38818019011137983, 8: 0.09059044312245956, 13: 0.018695338397040958}
#
# Predicted class: 6
# Class probabilities: {1: 0.055155804428867465, 2: 0.029983388685192614, 3: 0.06799367481933564, 4: 0.12907457645426726, 5: 0.04799517474511024, 6: 0.4718574512208071, 7: 0.08811809638063678, 8: 0.0835750754151444, 13: 0.026246757850638573}
#
# Predicted class: 3
# Class probabilities: {1: 0.1292186456779771, 2: 0.1266252668170817, 3: 0.21581266752241585, 4: 0.1478140830772335, 5: 0.08827058806085122, 6: 0.09399839303328592, 7: 0.0826123674162012, 8: 0.08529778472829072, 13: 0.030350203666662714}
#
# Predicted class: 8
# Class probabilities: {1: 0.051601929482675724, 2: 0.015248900823016477, 3: 0.05170528578789733, 4: 0.059608229519318746, 5: 0.03441502970394539, 6: 0.09033703140718793, 7: 0.07013442711112898, 8: 0.5315002949167814, 13: 0.09544887124804798}
#
# Predicted class: 8
# Class probabilities: {1: 0.03665561366402538, 2: 0.0020749527916064992, 3: 0.08434912224941786, 4: 0.018024475189501402, 5: 0.014070154623438923, 6: 0.03898096904152319, 7: 0.021471017431213088, 8: 0.7114013166074447, 13: 0.07297237840182888}
#
# Predicted class: 4
# Class probabilities: {1: 0.08602210434427889, 2: 0.057051888828729136, 3: 0.09564650255530055, 4: 0.2432095863839873, 5: 0.18415824620792265, 6: 0.1690671382725591, 7: 0.07858720616757926, 8: 0.06409760512473546, 13: 0.02215972211490748}
#
# Predicted class: 1
# Class probabilities: {1: 0.6017935705734732, 2: 0.03772375565001129, 3: 0.0830243879940482, 4: 0.05528227441786182, 5: 0.032224396270835926, 6: 0.05722492459852262, 7: 0.03145231986033782, 8: 0.0922160461365508, 13: 0.009058324498358144}
#
# Predicted class: 8
# Class probabilities: {1: 0.05247981894283859, 2: 0.0042316359181091045, 3: 0.05456193048308179, 4: 0.03815473248770548, 5: 0.010178608389595027, 6: 0.03414244357535762, 7: 0.028551403654498497, 8: 0.7152531723584684, 13: 0.062446254190345246}
#
# Predicted class: 7
# Class probabilities: {1: 0.05954744644560348, 2: 0.013724773906856272, 3: 0.05173160142551062, 4: 0.08945446316739711, 5: 0.025804448580662682, 6: 0.1762174114645129, 7: 0.506551390794824, 8: 0.06957704988135696, 13: 0.007391414333275878}

# %%
# 예를 들어, 모델이 2개의 피처로 학습된 경우

# 사용자 입력 피처
user_input_feature = [[5, 1, 1]]  # 예: 2개의 피처 값

# 예측 결과 얻기
prediction = rfc.predict(user_input_feature)

# 예측 결과 출력
predicted_value = prediction[0]
print(f"The predicted target value for the feature values {user_input_feature[0]} is {predicted_value}")
# Out:
# The predicted target value for the feature values [5, 1, 1] is 1

# %%
import pandas as pd
import numpy as np

# RFC 모델로부터 최적의 추정기 가져오기
rfc = g_rfc.best_estimator_

# 사용자가 입력한 피처 값
user_input_feature = [[3, 2, 1]]

# 예측 확률 얻기
prediction_proba = rfc.predict_proba(user_input_feature)

# 상위 3개의 확률에 해당하는 클래스 추출
top_3_indices = np.argsort(prediction_proba[0])[-1:][::-1]
top_3_classes = rfc.classes_[top_3_indices]

print("Top 3 predicted classes:", top_3_classes)

# 필터링된 결과 출력
filtered_df = pre_t_df[pre_t_df['club_main_category_id(target)'].isin(top_3_classes)]

print(f"Rows where target matches the top 3 predicted values {top_3_classes}:")
# Out:
# Top 3 predicted classes: [1]
# Rows where target matches the top 3 predicted values [1]:

# %%
top_3_classes
# Out:
# array([1])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.2

# %%
# default 파일로 저장하기
import pickle
import joblib

joblib.dump(rfc,'rfc_default_model.pkl')
# Out:
# ['rfc_default_model.pkl']

# %%
# pip install scikit-learn==1.4.2
