# %%
# 클럽 리스트 확인

import pandas as pd
import numpy as np

c_df = pd.read_csv('./club_list.csv')
c_df
# Out:
#       id    club_name                                   club_intro  \
# 0     48  미니어쳐 공예 클래스        미니어쳐 공예 클래스는 취미에 관심이 많은 분들을 위한 모임입니다.
# 1     52           순간                 순간는 취미에 관심이 많은 분들을 위한 모임입니다.
# 2     54          실바꿈        취미을(를) 좋아하는 사람들이 모인 실바꿈에 오신 것을 환영합니다.
# 3     70         일취월장       취미을(를) 좋아하는 사람들이 모인 일취월장에 오신 것을 환영합니다.
# 4     78          카그그        취미을(를) 좋아하는 사람들이 모인 카그그에 오신 것을 환영합니다.
# ..   ...          ...                                          ...
# 462  468   잘 노는 공부쟁이들  이 모임, 잘 노는 공부쟁이들는 스터디에 흥미를 가진 분들이 모이는 곳입니다.
# 463  469      게으른 책읽기           게으른 책읽기는 스터디에 관심이 많은 분들을 위한 모임입니다.
# 464  479            W         스터디을(를) 좋아하는 사람들이 모인 W에 오신 것을 환영합니다.
# 465  485          시너지       스터디을(를) 좋아하는 사람들이 모인 시너지에 오신 것을 환영합니다.
# 466   35          꼬꼬봉               꼬꼬봉는 기타 관련 다양한 활동을 함께하는 모임입니다.
#
#      club_main_category_id category_name
# 0                        1            취미
# 1                        1            취미
# ...

# %%
# value_counts 결과를 DataFrame으로 변환
counts = c_df[['club_main_category_id', 'category_name']].value_counts().reset_index(name='counts')

# club_main_category_id를 기준으로 정렬
sorted_counts = counts.sort_values(by='club_main_category_id')

# 결과 출력
sorted_counts
# Out:
#     club_main_category_id category_name  counts
# 2                       1            취미      68
# 3                       2         문화·예술      64
# 0                       3       운동·액티비티     107
# 7                       4        푸드·드링크      21
# 4                       5         여행·동행      40
# 1                       6       성장·자기개발      70
# 8                       7         동네·또래      19
# 9                       8        연애·소개팅      15
# 10                      9           재테크      11
# 6                      10           외국어      22
# 5                      11           스터디      29
# 11                     13            기타       1

# %%
# 랜덤 titile 확인

import pandas as pd
import numpy as np

# CSV 파일 목록
file_list = ['./youtube_another.csv', './youtube_culture.csv', './youtube_festival.csv', 
             './youtube_food.csv', './youtube_hobby.csv', './youtube_love.csv',
             './youtube_sport.csv', './youtube_stock.csv', './youtube_travel.csv']

# 각 CSV 파일을 읽어서 데이터프레임 리스트로 저장
df_list = [pd.read_csv(file) for file in file_list]

# 모든 데이터프레임을 세로로 결합
all_df = pd.concat(df_list, axis=0, ignore_index=True)

# 결과 출력
all_df
# Out:
#              created_date         updated_date  \
# 0     2024-04-24 12:29:30  2024-05-19 22:28:02
# 1     2024-02-06 15:32:27  2024-05-19 22:28:02
# 2     2024-02-19 14:04:46  2024-05-19 22:28:02
# 3     2024-02-09 21:23:57  2024-05-19 22:28:02
# 4      2024-03-23 8:07:11  2024-05-19 22:28:02
# ...                   ...                  ...
# 4113  2024-02-12 21:30:49  2024-05-19 22:49:17
# 4114  2024-02-26 17:43:57  2024-05-19 22:49:17
# 4115   2024-05-18 9:08:10  2024-05-19 22:49:17
# 4116   2024-05-02 0:22:33  2024-05-19 22:49:17
# 4117   2024-03-09 7:42:33  2024-05-19 22:49:17
#
#                                          teenplay_title  \
# 0     걸그룹 ♬♡ 최신 노래 시원하게 말아줄게 ♬ M/V 4K 뮤비 노래 모음 플리 30...
# 1      걸그룹 ♬♡ 트리플에스 (tripleS) M/V 4K 뮤비 노래 모음 플리 10곡 ♬♡
# 2           추억이 된 걸그룹 ♬♡ 여자친구 뮤비 노래 모음 플리 14곡 ♬♡ (재업로드)
# 3     미친 연습량 걸그룹 ♬♡ 퍼포먼스 비디오 노동요 ♬ M/V 4K 뮤비 노래 모음 플...
# 4          걸그룹 트와이스 ♬♡ 솔로곡 포함 M/V 4K 뮤비 노래 모음 플리 26곡 ♬♡
# ...

# %%
import pandas as pd
import numpy as np


# 각 카테고리에 해당하는 id 값 리스트 생성
id_lists = {
    '취미': c_df[c_df['category_name'] == '취미']['id'].tolist(),
    '문화·예술': c_df[c_df['category_name'] == '문화·예술']['id'].tolist(),
    '운동·액티비티': c_df[c_df['category_name'] == '운동·액티비티']['id'].tolist(),
    '푸드·드링크': c_df[c_df['category_name'] == '푸드·드링크']['id'].tolist(),
    '여행·동행': c_df[c_df['category_name'] == '여행·동행']['id'].tolist(),
    '성장·자기개발': c_df[c_df['category_name'] == '성장·자기개발']['id'].tolist(),
    '연애·소개팅': c_df[c_df['category_name'] == '연애·소개팅']['id'].tolist(),
    '재테크': c_df[c_df['category_name'] == '재테크']['id'].tolist(),
    '외국어': c_df[c_df['category_name'] == '외국어']['id'].tolist(),
    '스터디': c_df[c_df['category_name'] == '스터디']['id'].tolist(),
    '기타': c_df[c_df['category_name'] == '기타']['id'].tolist()
}

# club_id 열 추가하고 조건에 맞는 경우 랜덤 값 할당, 그렇지 않은 경우 NaN 할당
all_df['club_id'] = np.nan  # 초기값은 NaN으로 설정

for category, id_list in id_lists.items():
    all_df.loc[all_df['club_main_category_id'] == category, 'club_id'] = np.random.choice(id_list, size=(all_df['club_main_category_id'] == category).sum(), replace=True)

# 결측치에 대해 '문화·예술' 리스트에서 랜덤 값 할당
all_df['club_id'] = all_df['club_id'].apply(lambda x: np.random.choice(id_lists['문화·예술']) if pd.isna(x) else x)

# 결과 출력
all_df
# Out:
#              created_date         updated_date  \
# 0     2024-04-24 12:29:30  2024-05-19 22:28:02
# 1     2024-02-06 15:32:27  2024-05-19 22:28:02
# 2     2024-02-19 14:04:46  2024-05-19 22:28:02
# 3     2024-02-09 21:23:57  2024-05-19 22:28:02
# 4      2024-03-23 8:07:11  2024-05-19 22:28:02
# ...                   ...                  ...
# 4113  2024-02-12 21:30:49  2024-05-19 22:49:17
# 4114  2024-02-26 17:43:57  2024-05-19 22:49:17
# 4115   2024-05-18 9:08:10  2024-05-19 22:49:17
# 4116   2024-05-02 0:22:33  2024-05-19 22:49:17
# 4117   2024-03-09 7:42:33  2024-05-19 22:49:17
#
#                                          teenplay_title  \
# 0     걸그룹 ♬♡ 최신 노래 시원하게 말아줄게 ♬ M/V 4K 뮤비 노래 모음 플리 30...
# 1      걸그룹 ♬♡ 트리플에스 (tripleS) M/V 4K 뮤비 노래 모음 플리 10곡 ♬♡
# 2           추억이 된 걸그룹 ♬♡ 여자친구 뮤비 노래 모음 플리 14곡 ♬♡ (재업로드)
# 3     미친 연습량 걸그룹 ♬♡ 퍼포먼스 비디오 노동요 ♬ M/V 4K 뮤비 노래 모음 플...
# 4          걸그룹 트와이스 ♬♡ 솔로곡 포함 M/V 4K 뮤비 노래 모음 플리 26곡 ♬♡
# ...

# %%
result_df = all_df.drop(labels = ['club_main_category_id'], axis =1)
result_df
result_df.to_csv('result.csv', index=False, encoding='utf-8-sig')

# %%
pre_t_df = all_df.drop(labels = ['teenplay_title', 'club_id', 'created_date', 'updated_date', 'video_path', 'thumnail_path', 'status'], axis =1)
pre_t_df
# Out:
#      club_main_category_id
# 0                       기타
# 1                       기타
# 2                       기타
# 3                       기타
# 4                       기타
# ...                    ...
# 4113                 여행·동행
# 4114                 여행·동행
# 4115                 여행·동행
# 4116                 여행·동행
# 4117                 여행·동행
#
# [4118 rows x 1 columns]

# %%
def assign_value_based_on_column(value):
    if value =='취미':
        return 1
    elif value == "문화·예술":
        return 2
    elif value == "운동·액티비티":
        return 3
    elif value == "푸드·드링크":
        return 4
    elif value == "여행·동행":
        return 5
    elif value == "성장·자기개발":
        return 6
    elif value == "동네·또래":
        return 7
    elif value == "연애·소개팅":
        return 8
    elif value == "재테크":
        return 9
    elif value == "외국어":
        return 10
    elif value == "스터디":
        return 11
    else:
        return 13

# %%
pre_t_df['club_main_category_id'] = pre_t_df['club_main_category_id'].apply(assign_value_based_on_column)
pre_t_df
# Out:
#       club_main_category_id
# 0                        13
# 1                        13
# 2                        13
# 3                        13
# 4                        13
# ...                     ...
# 4113                      5
# 4114                      5
# 4115                      5
# 4116                      5
# 4117                      5
#
# [4118 rows x 1 columns]

# %%
import numpy as np
# 1부터 13까지의 숫자 중 12를 제외한 리스트
choices = list(range(1, 12)) + [13]

# 예제 데이터프레임이므로 user_like_category와 user_category(target) 열을 임의로 생성
pre_t_df['user_like_category'] = np.random.choice(choices, size=len(all_df))
pre_t_df['wish_list_category'] = np.random.choice(choices, size=len(all_df))
# pre_t_df['user_category(target)'] = np.random.choice(choices, size=len(all_df))
pre_t_df


# # # club_id 열을 조건부 할당하여 추가
# all_df['club_category'] = all_df['club_main_category_id'].apply(assign_value_based_on_column)

# # # 결과 출력
display(pre_t_df)
# Out:
#       club_main_category_id  user_like_category  wish_list_category
# 0                        13                   8                  13
# 1                        13                   7                   6
# 2                        13                  11                  13
# 3                        13                   5                  13
# 4                        13                   3                   6
# ...                     ...                 ...                 ...
# 4113                      5                  10                   3
# 4114                      5                   7                   3
# 4115                      5                   3                   2
# 4116                      5                   3                   1
# 4117                      5                   6                   5
#
# [4118 rows x 3 columns]

# %%
def match_categories(df, like_col, target_col, ratio=(3, 7)):
    like_values = df[like_col].value_counts().index
    for value in like_values:
        like_indices = df[df[like_col] == value].index
        num_target = int(len(like_indices) * ratio[1] / sum(ratio))
        target_indices = np.random.choice(like_indices, size=num_target, replace=False)
        df.loc[target_indices, target_col] = value
    return df

# %%
# # club_category(target) 열 생성
pre_t_df['user_category(target)'] = np.nan

# user_like_category와 club_category(target) 값을 3:7 비율로 맞춤
pre_t_df = match_categories(pre_t_df, 'club_main_category_id', 'user_category(target)')

# 결측치 채우기: 남아 있는 결측치에 대해 임의의 값으로 채움 (여기서는 같은 비율로 채우기)
remaining_indices = pre_t_df['user_category(target)'].isna()
num_remaining = remaining_indices.sum()
if num_remaining > 0:
    remaining_values = np.random.choice(pre_t_df['club_main_category_id'].unique(), size=num_remaining, replace=True)
    pre_t_df.loc[remaining_indices, 'user_category(target)'] = remaining_values


# 결과 출력
pre_t_df['user_category(target)'] = pre_t_df['user_category(target)'].astype(np.int64)
pre_t_df
# Out:
#       club_main_category_id  user_like_category  wish_list_category  \
# 0                        13                   8                  13
# 1                        13                   7                   6
# 2                        13                  11                  13
# 3                        13                   5                  13
# 4                        13                   3                   6
# ...                     ...                 ...                 ...
# 4113                      5                  10                   3
# 4114                      5                   7                   3
# 4115                      5                   3                   2
# 4116                      5                   3                   1
# 4117                      5                   6                   5
#
#       user_category(target)
# 0                        13
# 1                        13
# 2                        13
# 3                         8
# ...

# %%
pre_t_df.hist()
# Out:
# array([[<Axes: title={'center': 'club_main_category_id'}>,
#         <Axes: title={'center': 'user_like_category'}>],
#        [<Axes: title={'center': 'wish_list_category'}>,
#         <Axes: title={'center': 'user_category(target)'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier

features, targets = pre_t_df.iloc[:, :-1], pre_t_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size= 0.2, random_state=321)

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 결정트리 이미지 확인 후 dtc 의 최초 파라미터 확인
from sklearn.metrics import accuracy_score
print(dtc.max_depth)
print(dtc.min_samples_split)
print(dtc.feature_importances_)

# 교차 검증 이전 정확도 확인
prediction = dtc.predict(X_test)
acc_score = accuracy_score(y_test, prediction)
print('='* 50)
print(f"\n최초 정확도: {round(acc_score * 100,2)} %")
# Out:
# None
# 2
# [0.7438115  0.11959244 0.13659606]
# ...
#
# 최초 정확도: 63.83 %

# %%
# 교차 검증 진행 GridSearchCV
from sklearn.model_selection import GridSearchCV

parameters = {
    'max_depth': [5, 7, 9 ,10],
    'min_samples_split': [10, 20 ,30] 
}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=3, refit=True, return_train_score=True)
g_dtc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 7, 9, 10],
#                          'min_samples_split': [10, 20, 30]},
#              return_train_score=True)

# %%
# 교차 검증 이후 정확도 확인 
print(g_dtc.best_params_, g_dtc.best_score_, sep='\n')
dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

acc_score = accuracy_score(y_test, prediction)
print('='* 50)
print(f"\n교차검증 이후 정확도: {round(acc_score * 100,2)} %")
# Out:
# {'max_depth': 7, 'min_samples_split': 30}
# 0.7349726775956285
# ...
#
# 교차검증 이후 정확도: 74.88 %

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='micro')
    recall = recall_score(y_test , prediction, average='micro')
    f1 = f1_score(y_test, prediction, average='micro')
    # auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,8))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[ 32   4   3   2   5   0   4   7]
#  [  1  68   1   1   9   4   4   4]
#  [  2   4  62   1   8   3   4   8]
#  [  1   2   7  45   4   4   4   4]
#  [  1   2   3   5  90   3   6   5]
#  [  1   3   5   2   4  89   7   7]
#  [  1   6   3   3   3   5 129   3]
#  [  0   2   2   1   1   7  11 102]]
# 정확도: 0.7488, 정밀도: 0.7488, 재현율: 0.7488, F1: 0.7488
# ################################################################################

# %%
# parameters = {
#     'C': [10, 100, 1000, 10000],
#     'gamma': [10, 100, 1000],
#     'kernel': ['linear']
# }

# svc = SVC(probability=True)

# g_svc = GridSearchCV(svc, param_grid=parameters, cv=3, refit=True, return_train_score=True)
# g_svc.fit(X_train, y_train)

# %%
# svc = g_svc.best_estimator_
# prediction = g_svc.predict(X_test)

# %%
# get_evaluation(y_test, prediction, svc, X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_c = KNeighborsClassifier()

parameters = {
    'n_neighbors' : [3, 5, 7, 9, 11]
}

g_knn_c = GridSearchCV(knn_c, param_grid=parameters, cv=3, refit=True, return_train_score=True)
g_knn_c.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[ 15  21   4   1   5   1   3   7]
#  [  0  68   2   1   9   4   4   4]
#  [  2  10  56   1   8   4   3   8]
#  [  0   3   9  36  12   3   4   4]
#  [  1   1   4   4  90   4   6   5]
#  [  1   4   5   4  20  68   9   7]
#  [  0   7   5   0   6   7 125   3]
#  [  0   2   2   1   3   6  12 100]]
# 정확도: 0.6772, 정밀도: 0.6772, 재현율: 0.6772, F1: 0.6772
# ################################################################################

# %%
# 데이터의 훈련 시 시간이 얼마나 걸릴 지 모르기 때문에 우선 1부터 조금씩 낮아지도록 훈련 진행
from sklearn.ensemble import AdaBoostClassifier

parameters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.7, 0.8, 0.9, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid= parameters, cv=3, refit=True, return_train_score=True, n_jobs = -1)

# %%
knn_c = g_knn_c.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[ 15  21   4   1   5   1   3   7]
#  [  0  68   2   1   9   4   4   4]
#  [  2  10  56   1   8   4   3   8]
#  [  0   3   9  36  12   3   4   4]
#  [  1   1   4   4  90   4   6   5]
#  [  1   4   5   4  20  68   9   7]
#  [  0   7   5   0   6   7 125   3]
#  [  0   2   2   1   3   6  12 100]]
# 정확도: 0.6772, 정밀도: 0.6772, 재현율: 0.6772, F1: 0.6772
# ################################################################################

# %%
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'max_depth' : [8, 9, 10],
    'min_samples_split' : [50, 100, 150]
}

rfc = RandomForestClassifier(n_estimators=70)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=3, n_jobs= -1)

# %%
g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=70), n_jobs=-1,
#              param_grid={'max_depth': [8, 9, 10],
#                          'min_samples_split': [50, 100, 150]})

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[  3  29   7   2   5   0   4   7]
#  [  0  67   3   1   9   4   4   4]
#  [  0   5  64   0   8   3   4   8]
#  [  0   2  11  41   5   4   4   4]
#  [  0   2   4   2  93   3   6   5]
#  [  0   4   5   2   4  89   7   7]
#  [  0   6   5   2   3   5 129   3]
#  [  0   2   2   1   1   7  11 102]]
# 정확도: 0.7136, 정밀도: 0.7136, 재현율: 0.7136, F1: 0.7136
# ################################################################################

# %%
from lightgbm import LGBMClassifier

parameters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.7, 0.8, 0.9, 1]
}

X_val_train, X_val_test, y_val_train, y_val_test =\
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=321)

evals= [(X_val_train, y_val_train), (X_val_test, y_val_test)]
g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
g_lgbm.fit(X_train, y_train, eval_set=evals)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001121 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 2196, number of used features: 3
# [LightGBM] [Info] Start training from score -2.670512
# [LightGBM] [Info] Start training from score -2.189061
# [LightGBM] [Info] Start training from score -2.193135
# [LightGBM] [Info] Start training from score -2.452646
# [LightGBM] [Info] Start training from score -1.964293
# [LightGBM] [Info] Start training from score -1.948190
# [LightGBM] [Info] Start training from score -1.683126
# [LightGBM] [Info] Start training from score -1.880262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.7, 'n_estimators': 50}         0.163631
# 1   {'learning_rate': 0.7, 'n_estimators': 100}         0.163631
# 2   {'learning_rate': 0.7, 'n_estimators': 150}         0.163631
# 3    {'learning_rate': 0.8, 'n_estimators': 50}         0.182149
# 4   {'learning_rate': 0.8, 'n_estimators': 100}         0.182149
# 5   {'learning_rate': 0.8, 'n_estimators': 150}         0.182149
# 6    {'learning_rate': 0.9, 'n_estimators': 50}         0.156952
# 7   {'learning_rate': 0.9, 'n_estimators': 100}         0.156952
# 8   {'learning_rate': 0.9, 'n_estimators': 150}         0.156952
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.145719
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.145719
# 11    {'learning_rate': 1, 'n_estimators': 150}         0.145719
#
#     rank_test_score
# 0                 4
# 1                 4
# 2                 4
# 3                 1
# ...

# %%
lgbm = g_lgbm.best_estimator_
prediction = g_lgbm.predict(X_test)

# %%
get_evaluation(y_test, prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[  3   1   2   0  34   6   1  10]
#  [  3   6   0   0  57   1   4  21]
#  [  3   2   1   0  55   7   6  18]
#  [  0   2   3   0  41   7   8  10]
#  [  6   5   3   0  70   9   7  15]
#  [  4   1   8   0  76   4   6  19]
#  [  2   1  12   0 103   0  15  20]
#  [  2   1   1   0  91   1   8  22]]
# 정확도: 0.1468, 정밀도: 0.1468, 재현율: 0.1468, F1: 0.1468
# ################################################################################

# %%
# import matplotlib.pyplot as plt
# import matplotlib.ticker as ticker
# from sklearn.metrics import precision_recall_curve

# def precision_recall_curve_plot(y_test , prediction_proba_class1):

#     precisions, recalls, thresholds = precision_recall_curve(y_test, prediction_proba_class1)
    
#     # X축: threshold
#     # Y축: 정밀도, 재현율 
#     # 정밀도는 점선으로 표시
#     plt.figure(figsize=(8,6))
#     threshold_boundary = thresholds.shape[0]
#     plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
#     plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
#     # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
#     start, end = plt.xlim()
#     plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
#     plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
#     plt.legend()
#     plt.grid()
#     plt.show()
    
# precision_recall_curve_plot(y_test, lgbm.predict_proba(X_test)[:, 1] )

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize

def precision_recall_curve_multiclass(y_test, prediction_proba):
    n_classes = prediction_proba.shape[1]
    y_test_binarized = label_binarize(y_test, classes=np.arange(n_classes))
    
    # 서브플롯 그리드 크기 설정 (최대 2x2 그리드로 설정)
    rows = (n_classes + 1) // 2
    plt.figure(figsize=(16, 12))
    thresholds_list = []

    for i in range(n_classes):
        if np.sum(y_test_binarized[:, i]) == 0:
            print(f"Class {i} has no positive samples in y_test, skipping precision-recall curve.")
            continue

        precisions, recalls, thresholds = precision_recall_curve(y_test_binarized[:, i], prediction_proba[:, i])
        thresholds_list.append(thresholds)
        
        plt.subplot(rows, 2, i + 1)
        threshold_boundary = thresholds.shape[0]
        plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
        plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
        
        start, end = plt.xlim()
        plt.xticks(np.round(np.arange(start, end, 0.1), 2))
        
        plt.xlabel('Threshold value')
        plt.ylabel('Precision and Recall value')
        plt.title(f'Class {i} Precision-Recall Curve')
        plt.legend()
        plt.grid()
    
    plt.tight_layout()
    plt.show()
    
    return thresholds_list

# %%
# 예제 사용법 (실제 데이터셋과 모델의 예측 확률 사용)
# 예: y_test는 테스트 셋의 실제 레이블, lgbm은 LightGBM 모델, X_test는 테스트 셋의 피처
thresholds = precision_recall_curve_multiclass(y_test, lgbm.predict_proba(X_test))
print(thresholds)
# Out:
# Class 0 has no positive samples in y_test, skipping precision-recall curve.
# Class 1 has no positive samples in y_test, skipping precision-recall curve.
# [array([0.00000000e+000, 4.35090259e-247, 1.00000000e+000, 1.00000000e+000]), array([0.00000000e+00, 2.59018961e-28]), array([0.00000000e+000, 9.44557809e-292, 1.17465087e-157, 1.51604708e-084,
#        1.00000000e+000]), array([0.00000000e+000, 2.05084525e-215, 7.92089578e-137, 4.33922979e-101,
#        1.00000000e+000, 1.00000000e+000]), array([0., 1.]), array([0.00000000e+000, 7.22215615e-210, 4.42252531e-094, 3.10356704e-090,
#        2.17003322e-067, 1.43638772e-025, 1.00000000e+000])]

# %%
def get_evaluation_by_thresholds(y_test, prediction_proba_class1, thresholds):
    for threshold in thresholds:
        binarizer = Binarizer(threshold=threshold).fit(prediction_proba_class1) 
        custom_prediction = binarizer.transform(prediction_proba_class1)
        print('임곗값:', threshold)
        get_evaluation(y_test, custom_prediction)

# %%
thresholds = np.array(thresholds).flatten()
get_evaluation_by_thresholds(y_test, lgbm.predict_proba(X_test)[:, 1], thresholds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 thresholds = np.array(thresholds).flatten()
#       2 get_evaluation_by_thresholds(y_test, lgbm.predict_proba(X_test)[:, 1], thresholds)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.

# %%
# 각 클래스의 임곗값을 리스트로 저장합니다.
thresholds_list = []

# 예측 확률과 y_test를 이진화합니다.
from sklearn.preprocessing import label_binarize
n_classes = len(np.unique(y_test))
y_test_binarized = label_binarize(y_test, classes=[*range(n_classes)])

for i in range(n_classes):
    precision, recall, thresholds = precision_recall_curve(y_test_binarized[:, i], lgbm.predict_proba(X_test)[:, i])
    thresholds_list.append(thresholds)

# 각 클래스의 임곗값 확인
for class_idx, class_thresholds in enumerate(thresholds_list):
    print(f"Class {class_idx} thresholds: {class_thresholds}")

def get_evaluation_by_thresholds(y_test, prediction_proba_class1, thresholds):
    for threshold in thresholds:
        binarizer = Binarizer(threshold=threshold).fit(prediction_proba_class1.reshape(-1, 1))
        custom_prediction = binarizer.transform(prediction_proba_class1.reshape(-1, 1))
        print('임곗값:', threshold)
        get_evaluation(y_test, custom_prediction)

# 클래스별로 임곗값 평가
for class_idx, class_thresholds in enumerate(thresholds_list):
    print(f"Class {class_idx} thresholds evaluation:")
    get_evaluation_by_thresholds(y_test_binarized[:, class_idx], lgbm.predict_proba(X_test)[:, class_idx], class_thresholds)

# %%
# LightGBM 모델로부터 최적의 추정기 가져오기
lgbm = g_lgbm.best_estimator_

# 사용자가 입력한 피처 값
user_input_feature = [[4, 4, 4]]

# 예측 결과 얻기
prediction = lgbm.predict(user_input_feature)

# 예측 결과 출력
predicted_value = prediction[0]
print(f"The predicted target value for the feature value {user_input_feature[0][0]} is {predicted_value}")

# 예측 결과에 따라 추가 작업 수행 (예: 타겟 값이 예측 값과 일치하는 행 필터링)
filtered_df = pre_t_df[pre_t_df['club_category(target)'] == predicted_value]

# 필터링된 결과 출력
print(f"Rows where target matches the predicted value {predicted_value}:")
filtered_df

# %%
# 예를 들어, 모델이 2개의 피처로 학습된 경우

# 사용자 입력 피처
user_input_feature = [[4, 4, 4]]  # 예: 2개의 피처 값

# 예측 결과 얻기
prediction = dtc.predict(user_input_feature)

# 예측 결과 출력
predicted_value = prediction[0]
print(f"The predicted target value for the feature values {user_input_feature[0]} is {predicted_value}")

# %%
import pandas as pd
import numpy as np

# LightGBM 모델로부터 최적의 추정기 가져오기
lgbm = g_lgbm.best_estimator_

# 사용자가 입력한 피처 값
user_input_feature = [[2, 2, 2]]

# 예측 확률 얻기
prediction_proba = lgbm.predict_proba(user_input_feature)

# 상위 3개의 확률에 해당하는 클래스 추출
top_3_indices = np.argsort(prediction_proba[0])[-3:][::-1]
top_3_classes = lgbm.classes_[top_3_indices]

# 필터링된 결과 출력
filtered_df = pre_t_df[pre_t_df['club_category(target)'].isin(top_3_classes)]

print(f"Rows where target matches the top 3 predicted values {top_3_classes}:")
filtered_df[filtered_df['club_category(target)'] == 4]

# %%
top_3_classes

# %%
filtered_df['club_category(target)'].value_counts()
